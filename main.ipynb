# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
Apple = yf.download('AAPL', start='2010-01-01', end='2021-01-01')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
Apple
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-01-04    7.622500    7.660714    7.585000    7.643214    6.478998
# 2010-01-05    7.664286    7.699643    7.616071    7.656429    6.490200
# 2010-01-06    7.656429    7.686786    7.526786    7.534643    6.386966
# 2010-01-07    7.562500    7.571429    7.466071    7.520714    6.375156
# 2010-01-08    7.510714    7.571429    7.466429    7.570714    6.417541
# ...                ...         ...         ...         ...         ...
# 2020-12-24  131.320007  133.460007  131.100006  131.970001  129.679749
# 2020-12-28  133.990005  137.339996  133.509995  136.690002  134.317841
# 2020-12-29  138.050003  138.789993  134.339996  134.869995  132.529388
# 2020-12-30  135.580002  135.990005  133.399994  133.720001  131.399353
# 2020-12-31  134.080002  134.740005  131.720001  132.690002  130.387222
#
#                Volume
# Date
# 2010-01-04  493729600
# 2010-01-05  601904800
# 2010-01-06  552160000
# 2010-01-07  477131200
# 2010-01-08  447610800
# ...               ...
# 2020-12-24   54930100
# 2020-12-28  124486200
# 2020-12-29  121047300
# 2020-12-30   96452100
# 2020-12-31   99116600
#
# [2769 rows x 6 columns]

# %%
a = [1,2,3,5]
a
# Out:
# [1, 2, 3, 5]

# %%
ticker=["SPY","AAPL","KO"]

# %%
stocks = yf.download(ticker, start='2010-01-01', end='2021-01-01')
# Out:
# [*********************100%%**********************]  3 of 3 completed

# %%
stocks
# Out:
#              Adj Close                              Close             \
#                   AAPL         KO         SPY        AAPL         KO
# Date
# 2010-01-04    6.478999  18.498022   87.129974    7.643214  28.520000
# 2010-01-05    6.490201  18.274248   87.360603    7.656429  28.174999
# 2010-01-06    6.386965  18.267769   87.422081    7.534643  28.165001
# 2010-01-07    6.375156  18.222361   87.791130    7.520714  28.094999
# 2010-01-08    6.417542  17.885094   88.083275    7.570714  27.575001
# ...                ...        ...         ...         ...        ...
# 2020-12-24  129.679749  48.779102  352.967987  131.970001  53.439999
# 2020-12-28  134.317810  49.436314  356.000275  136.690002  54.160000
# 2020-12-29  132.529388  49.408924  355.321106  134.869995  54.130001
# 2020-12-30  131.399399  49.691887  355.828125  133.720001  54.439999
# 2020-12-31  130.387207  50.057003  357.636017  132.690002  54.840000
#
#                               High                                Low  \
#                    SPY        AAPL         KO         SPY        AAPL
# Date
# 2010-01-04  113.330002    7.660714  28.610001  113.389999    7.585000
# 2010-01-05  113.629997    7.699643  28.495001  113.680000    7.616071
# 2010-01-06  113.709999    7.686786  28.219999  113.989998    7.526786
# 2010-01-07  114.190002    7.571429  28.184999  114.330002    7.466071
# 2010-01-08  114.570000    7.571429  27.820000  114.620003    7.466429
# ...                ...         ...        ...         ...         ...
# 2020-12-24  369.000000  133.460007  53.549999  369.029999  131.100006
# 2020-12-28  372.170013  137.339996  54.439999  372.589996  133.509995
# 2020-12-29  371.459991  138.789993  54.490002  374.000000  134.339996
# 2020-12-30  371.989990  135.990005  54.630001  373.100006  133.399994
# 2020-12-31  373.880005  134.740005  54.930000  374.660004  131.720001
#
#                                          Open                         \
#                    KO         SPY        AAPL         KO         SPY
# Date
# 2010-01-04  28.450001  111.510002    7.622500  28.580000  112.370003
# 2010-01-05  28.070000  112.849998    7.664286  28.424999  113.260002
# 2010-01-06  27.990000  113.430000    7.656429  28.174999  113.519997
# 2010-01-07  27.875000  113.180000    7.562500  28.165001  113.500000
# 2010-01-08  27.375000  113.660004    7.510714  27.730000  113.889999
# ...               ...         ...         ...        ...         ...
# 2020-12-24  53.020000  367.450012  131.320007  53.020000  368.079987
# 2020-12-28  53.730000  371.070007  133.990005  53.849998  371.739990
# 2020-12-29  54.020000  370.829987  138.050003  54.450001  373.809998
# 2020-12-30  54.029999  371.570007  135.580002  54.049999  372.339996
# 2020-12-31  54.270000  371.230011  134.080002  54.450001  371.779999
#
#                Volume
#                  AAPL        KO        SPY
# Date
# 2010-01-04  493729600  13870400  118944600
# 2010-01-05  601904800  23172400  111579900
# 2010-01-06  552160000  19264600  116074400
# 2010-01-07  477131200  13234600  131091100
# 2010-01-08  447610800  28712400  126402800
# ...               ...       ...        ...
# 2020-12-24   54930100   3265500   26457900
# 2020-12-28  124486200   9020500   39000400
# 2020-12-29  121047300   8320600   53680500
# 2020-12-30   96452100   8142700   49455300
# 2020-12-31   99116600   8495000   78520700
#
# [2769 rows x 18 columns]

# %%
stocks.head()
# Out:
#            Adj Close                           Close                         \
#                 AAPL         KO        SPY      AAPL         KO         SPY
# Date
# 2010-01-04  6.478999  18.498022  87.129974  7.643214  28.520000  113.330002
# 2010-01-05  6.490201  18.274248  87.360603  7.656429  28.174999  113.629997
# 2010-01-06  6.386965  18.267769  87.422081  7.534643  28.165001  113.709999
# 2010-01-07  6.375156  18.222361  87.791130  7.520714  28.094999  114.190002
# 2010-01-08  6.417542  17.885094  88.083275  7.570714  27.575001  114.570000
#
#                 High                              Low                         \
#                 AAPL         KO         SPY      AAPL         KO         SPY
# Date
# 2010-01-04  7.660714  28.610001  113.389999  7.585000  28.450001  111.510002
# 2010-01-05  7.699643  28.495001  113.680000  7.616071  28.070000  112.849998
# 2010-01-06  7.686786  28.219999  113.989998  7.526786  27.990000  113.430000
# 2010-01-07  7.571429  28.184999  114.330002  7.466071  27.875000  113.180000
# 2010-01-08  7.571429  27.820000  114.620003  7.466429  27.375000  113.660004
#
#                 Open                            Volume
#                 AAPL         KO         SPY       AAPL        KO        SPY
# Date
# 2010-01-04  7.622500  28.580000  112.370003  493729600  13870400  118944600
# 2010-01-05  7.664286  28.424999  113.260002  601904800  23172400  111579900
# 2010-01-06  7.656429  28.174999  113.519997  552160000  19264600  116074400
# 2010-01-07  7.562500  28.165001  113.500000  477131200  13234600  131091100
# 2010-01-08  7.510714  27.730000  113.889999  447610800  28712400  126402800

# %%
stocks.tail()
# Out:
#              Adj Close                              Close             \
#                   AAPL         KO         SPY        AAPL         KO
# Date
# 2020-12-24  129.679749  48.779102  352.967987  131.970001  53.439999
# 2020-12-28  134.317810  49.436314  356.000275  136.690002  54.160000
# 2020-12-29  132.529388  49.408924  355.321106  134.869995  54.130001
# 2020-12-30  131.399399  49.691887  355.828125  133.720001  54.439999
# 2020-12-31  130.387207  50.057003  357.636017  132.690002  54.840000
#
#                               High                                Low  \
#                    SPY        AAPL         KO         SPY        AAPL
# Date
# 2020-12-24  369.000000  133.460007  53.549999  369.029999  131.100006
# 2020-12-28  372.170013  137.339996  54.439999  372.589996  133.509995
# 2020-12-29  371.459991  138.789993  54.490002  374.000000  134.339996
# 2020-12-30  371.989990  135.990005  54.630001  373.100006  133.399994
# 2020-12-31  373.880005  134.740005  54.930000  374.660004  131.720001
#
#                                          Open                         \
#                    KO         SPY        AAPL         KO         SPY
# Date
# 2020-12-24  53.020000  367.450012  131.320007  53.020000  368.079987
# 2020-12-28  53.730000  371.070007  133.990005  53.849998  371.739990
# 2020-12-29  54.020000  370.829987  138.050003  54.450001  373.809998
# 2020-12-30  54.029999  371.570007  135.580002  54.049999  372.339996
# 2020-12-31  54.270000  371.230011  134.080002  54.450001  371.779999
#
#                Volume
#                  AAPL       KO       SPY
# Date
# 2020-12-24   54930100  3265500  26457900
# 2020-12-28  124486200  9020500  39000400
# 2020-12-29  121047300  8320600  53680500
# 2020-12-30   96452100  8142700  49455300
# 2020-12-31   99116600  8495000  78520700

# %%
stocks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2769 entries, 2010-01-04 to 2020-12-31
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   (Adj Close, AAPL)  2769 non-null   float64
#  1   (Adj Close, KO)    2769 non-null   float64
#  2   (Adj Close, SPY)   2769 non-null   float64
#  3   (Close, AAPL)      2769 non-null   float64
#  4   (Close, KO)        2769 non-null   float64
#  5   (Close, SPY)       2769 non-null   float64
#  6   (High, AAPL)       2769 non-null   float64
#  7   (High, KO)         2769 non-null   float64
#  8   (High, SPY)        2769 non-null   float64
#  9   (Low, AAPL)        2769 non-null   float64
#  10  (Low, KO)          2769 non-null   float64
#  11  (Low, SPY)         2769 non-null   float64
#  12  (Open, AAPL)       2769 non-null   float64
#  13  (Open, KO)         2769 non-null   float64
#  14  (Open, SPY)        2769 non-null   float64
#  15  (Volume, AAPL)     2769 non-null   int64
#  16  (Volume, KO)       2769 non-null   int64
#  17  (Volume, SPY)      2769 non-null   int64
# dtypes: float64(15), int64(3)
# memory usage: 411.0 KB

# %%
stocks.to_csv("stocksYT.csv")

# %%
stocks = pd.read_csv("stocksYT.csv")

# %%
stocks
# Out:
#       Unnamed: 0           Adj Close         Adj Close.1         Adj Close.2  \
# 0            NaN                AAPL                  KO                 SPY
# 1           Date                 NaN                 NaN                 NaN
# 2     2010-01-04    6.47899866104126  18.498022079467773   87.12997436523438
# 3     2010-01-05   6.490200519561768  18.274248123168945   87.36060333251953
# 4     2010-01-06   6.386965274810791   18.26776885986328   87.42208099365234
# ...          ...                 ...                 ...                 ...
# 2766  2020-12-24  129.67974853515625   48.77910232543945   352.9679870605469
# 2767  2020-12-28  134.31781005859375   49.43631362915039   356.0002746582031
# 2768  2020-12-29  132.52938842773438    49.4089241027832  355.32110595703125
# 2769  2020-12-30  131.39939880371094   49.69188690185547          355.828125
# 2770  2020-12-31     130.38720703125  50.057003021240234   357.6360168457031
#
#                    Close             Close.1             Close.2  \
# 0                   AAPL                  KO                 SPY
# 1                    NaN                 NaN                 NaN
# 2      7.643214225769043  28.520000457763672  113.33000183105469
# 3      7.656428813934326  28.174999237060547  113.62999725341797
# 4      7.534643173217773  28.165000915527344  113.70999908447266
# ...                  ...                 ...                 ...
# 2766  131.97000122070312  53.439998626708984               369.0
# 2767  136.69000244140625   54.15999984741211   372.1700134277344
# 2768   134.8699951171875  54.130001068115234   371.4599914550781
# 2769  133.72000122070312  54.439998626708984    371.989990234375
# 2770  132.69000244140625   54.84000015258789   373.8800048828125
#
#                     High              High.1              High.2  \
# 0                   AAPL                  KO                 SPY
# 1                    NaN                 NaN                 NaN
# 2      7.660714149475098  28.610000610351562  113.38999938964844
# 3      7.699643135070801    28.4950008392334  113.68000030517578
# 4       7.68678617477417  28.219999313354492  113.98999786376953
# ...                  ...                 ...                 ...
# 2766   133.4600067138672   53.54999923706055   369.0299987792969
# 2767  137.33999633789062  54.439998626708984   372.5899963378906
# 2768   138.7899932861328    54.4900016784668               374.0
# 2769  135.99000549316406  54.630001068115234   373.1000061035156
# 2770  134.74000549316406   54.93000030517578   374.6600036621094
#
#                      Low               Low.1               Low.2  \
# 0                   AAPL                  KO                 SPY
# 1                    NaN                 NaN                 NaN
# 2      7.585000038146973  28.450000762939453  111.51000213623047
# 3     7.6160712242126465   28.06999969482422   112.8499984741211
# 4      7.526785850524902  27.989999771118164  113.43000030517578
# ...                  ...                 ...                 ...
# 2766  131.10000610351562   53.02000045776367  367.45001220703125
# 2767  133.50999450683594   53.72999954223633  371.07000732421875
# 2768  134.33999633789062   54.02000045776367   370.8299865722656
# 2769  133.39999389648438  54.029998779296875  371.57000732421875
# 2770  131.72000122070312   54.27000045776367   371.2300109863281
#
#                     Open              Open.1              Open.2     Volume  \
# 0                   AAPL                  KO                 SPY       AAPL
# 1                    NaN                 NaN                 NaN        NaN
# 2      7.622499942779541  28.579999923706055  112.37000274658203  493729600
# 3      7.664286136627197  28.424999237060547  113.26000213623047  601904800
# 4      7.656428813934326  28.174999237060547   113.5199966430664  552160000
# ...                  ...                 ...                 ...        ...
# 2766  131.32000732421875   53.02000045776367   368.0799865722656   54930100
# 2767  133.99000549316406  53.849998474121094    371.739990234375  124486200
# 2768   138.0500030517578   54.45000076293945  373.80999755859375  121047300
# 2769   135.5800018310547   54.04999923706055   372.3399963378906   96452100
# 2770   134.0800018310547   54.45000076293945   371.7799987792969   99116600
#
#       Volume.1   Volume.2
# 0           KO        SPY
# 1          NaN        NaN
# 2     13870400  118944600
# 3     23172400  111579900
# 4     19264600  116074400
# ...        ...        ...
# 2766   3265500   26457900
# 2767   9020500   39000400
# 2768   8320600   53680500
# 2769   8142700   49455300
# 2770   8495000   78520700
#
# [2771 rows x 19 columns]

# %%
stocks = pd.read_csv("stocksYT.csv",header=[0,1])
stocks
# Out:
#      Unnamed: 0_level_0   Adj Close                              Close  \
#      Unnamed: 0_level_1        AAPL         KO         SPY        AAPL
# 0                  Date         NaN        NaN         NaN         NaN
# 1            2010-01-04    6.478999  18.498022   87.129974    7.643214
# 2            2010-01-05    6.490201  18.274248   87.360603    7.656429
# 3            2010-01-06    6.386965  18.267769   87.422081    7.534643
# 4            2010-01-07    6.375156  18.222361   87.791130    7.520714
# ...                 ...         ...        ...         ...         ...
# 2765         2020-12-24  129.679749  48.779102  352.967987  131.970001
# 2766         2020-12-28  134.317810  49.436314  356.000275  136.690002
# 2767         2020-12-29  132.529388  49.408924  355.321106  134.869995
# 2768         2020-12-30  131.399399  49.691887  355.828125  133.720001
# 2769         2020-12-31  130.387207  50.057003  357.636017  132.690002
#
#                                    High                                Low  \
#              KO         SPY        AAPL         KO         SPY        AAPL
# 0           NaN         NaN         NaN        NaN         NaN         NaN
# 1     28.520000  113.330002    7.660714  28.610001  113.389999    7.585000
# 2     28.174999  113.629997    7.699643  28.495001  113.680000    7.616071
# 3     28.165001  113.709999    7.686786  28.219999  113.989998    7.526786
# 4     28.094999  114.190002    7.571429  28.184999  114.330002    7.466071
# ...         ...         ...         ...        ...         ...         ...
# 2765  53.439999  369.000000  133.460007  53.549999  369.029999  131.100006
# 2766  54.160000  372.170013  137.339996  54.439999  372.589996  133.509995
# 2767  54.130001  371.459991  138.789993  54.490002  374.000000  134.339996
# 2768  54.439999  371.989990  135.990005  54.630001  373.100006  133.399994
# 2769  54.840000  373.880005  134.740005  54.930000  374.660004  131.720001
#
#                                    Open                              Volume  \
#              KO         SPY        AAPL         KO         SPY         AAPL
# 0           NaN         NaN         NaN        NaN         NaN          NaN
# 1     28.450001  111.510002    7.622500  28.580000  112.370003  493729600.0
# 2     28.070000  112.849998    7.664286  28.424999  113.260002  601904800.0
# 3     27.990000  113.430000    7.656429  28.174999  113.519997  552160000.0
# 4     27.875000  113.180000    7.562500  28.165001  113.500000  477131200.0
# ...         ...         ...         ...        ...         ...          ...
# 2765  53.020000  367.450012  131.320007  53.020000  368.079987   54930100.0
# 2766  53.730000  371.070007  133.990005  53.849998  371.739990  124486200.0
# 2767  54.020000  370.829987  138.050003  54.450001  373.809998  121047300.0
# 2768  54.029999  371.570007  135.580002  54.049999  372.339996   96452100.0
# 2769  54.270000  371.230011  134.080002  54.450001  371.779999   99116600.0
#
#
#               KO          SPY
# 0            NaN          NaN
# 1     13870400.0  118944600.0
# 2     23172400.0  111579900.0
# 3     19264600.0  116074400.0
# 4     13234600.0  131091100.0
# ...          ...          ...
# 2765   3265500.0   26457900.0
# 2766   9020500.0   39000400.0
# 2767   8320600.0   53680500.0
# 2768   8142700.0   49455300.0
# 2769   8495000.0   78520700.0
#
# [2770 rows x 19 columns]

# %%
stocks = pd.read_csv("stocksYT.csv",header=[0,1],index_col=[0],parse_dates=[0])
stocks
# Out:
#              Adj Close                              Close             \
#                   AAPL         KO         SPY        AAPL         KO
# Date
# 2010-01-04    6.478999  18.498022   87.129974    7.643214  28.520000
# 2010-01-05    6.490201  18.274248   87.360603    7.656429  28.174999
# 2010-01-06    6.386965  18.267769   87.422081    7.534643  28.165001
# 2010-01-07    6.375156  18.222361   87.791130    7.520714  28.094999
# 2010-01-08    6.417542  17.885094   88.083275    7.570714  27.575001
# ...                ...        ...         ...         ...        ...
# 2020-12-24  129.679749  48.779102  352.967987  131.970001  53.439999
# 2020-12-28  134.317810  49.436314  356.000275  136.690002  54.160000
# 2020-12-29  132.529388  49.408924  355.321106  134.869995  54.130001
# 2020-12-30  131.399399  49.691887  355.828125  133.720001  54.439999
# 2020-12-31  130.387207  50.057003  357.636017  132.690002  54.840000
#
#                               High                                Low  \
#                    SPY        AAPL         KO         SPY        AAPL
# Date
# 2010-01-04  113.330002    7.660714  28.610001  113.389999    7.585000
# 2010-01-05  113.629997    7.699643  28.495001  113.680000    7.616071
# 2010-01-06  113.709999    7.686786  28.219999  113.989998    7.526786
# 2010-01-07  114.190002    7.571429  28.184999  114.330002    7.466071
# 2010-01-08  114.570000    7.571429  27.820000  114.620003    7.466429
# ...                ...         ...        ...         ...         ...
# 2020-12-24  369.000000  133.460007  53.549999  369.029999  131.100006
# 2020-12-28  372.170013  137.339996  54.439999  372.589996  133.509995
# 2020-12-29  371.459991  138.789993  54.490002  374.000000  134.339996
# 2020-12-30  371.989990  135.990005  54.630001  373.100006  133.399994
# 2020-12-31  373.880005  134.740005  54.930000  374.660004  131.720001
#
#                                          Open                         \
#                    KO         SPY        AAPL         KO         SPY
# Date
# 2010-01-04  28.450001  111.510002    7.622500  28.580000  112.370003
# 2010-01-05  28.070000  112.849998    7.664286  28.424999  113.260002
# 2010-01-06  27.990000  113.430000    7.656429  28.174999  113.519997
# 2010-01-07  27.875000  113.180000    7.562500  28.165001  113.500000
# 2010-01-08  27.375000  113.660004    7.510714  27.730000  113.889999
# ...               ...         ...         ...        ...         ...
# 2020-12-24  53.020000  367.450012  131.320007  53.020000  368.079987
# 2020-12-28  53.730000  371.070007  133.990005  53.849998  371.739990
# 2020-12-29  54.020000  370.829987  138.050003  54.450001  373.809998
# 2020-12-30  54.029999  371.570007  135.580002  54.049999  372.339996
# 2020-12-31  54.270000  371.230011  134.080002  54.450001  371.779999
#
#                Volume
#                  AAPL        KO        SPY
# Date
# 2010-01-04  493729600  13870400  118944600
# 2010-01-05  601904800  23172400  111579900
# 2010-01-06  552160000  19264600  116074400
# 2010-01-07  477131200  13234600  131091100
# 2010-01-08  447610800  28712400  126402800
# ...               ...       ...        ...
# 2020-12-24   54930100   3265500   26457900
# 2020-12-28  124486200   9020500   39000400
# 2020-12-29  121047300   8320600   53680500
# 2020-12-30   96452100   8142700   49455300
# 2020-12-31   99116600   8495000   78520700
#
# [2769 rows x 18 columns]

# %%
stocks.columns
# Out:
# MultiIndex([('Adj Close', 'AAPL'),
#             ('Adj Close',   'KO'),
#             ('Adj Close',  'SPY'),
#             (    'Close', 'AAPL'),
#             (    'Close',   'KO'),
#             (    'Close',  'SPY'),
#             (     'High', 'AAPL'),
#             (     'High',   'KO'),
#             (     'High',  'SPY'),
#             (      'Low', 'AAPL'),
#             (      'Low',   'KO'),
#             (      'Low',  'SPY'),
#             (     'Open', 'AAPL'),
#             (     'Open',   'KO'),
#             (     'Open',  'SPY'),
#             (   'Volume', 'AAPL'),
#             (   'Volume',   'KO'),
#             (   'Volume',  'SPY')],
#            )

# %%
# convert mult index to one tuple
stocks.columns = stocks.columns.to_flat_index()

# %%
stocks.columns
# Out:
# Index([('Adj Close', 'AAPL'),   ('Adj Close', 'KO'),  ('Adj Close', 'SPY'),
#            ('Close', 'AAPL'),       ('Close', 'KO'),      ('Close', 'SPY'),
#             ('High', 'AAPL'),        ('High', 'KO'),       ('High', 'SPY'),
#              ('Low', 'AAPL'),         ('Low', 'KO'),        ('Low', 'SPY'),
#             ('Open', 'AAPL'),        ('Open', 'KO'),       ('Open', 'SPY'),
#           ('Volume', 'AAPL'),      ('Volume', 'KO'),     ('Volume', 'SPY')],
#       dtype='object')

# %%
stocks
# Out:
#             (Adj Close, AAPL)  (Adj Close, KO)  (Adj Close, SPY)  \
# Date
# 2010-01-04           6.478999        18.498022         87.129974
# 2010-01-05           6.490201        18.274248         87.360603
# 2010-01-06           6.386965        18.267769         87.422081
# 2010-01-07           6.375156        18.222361         87.791130
# 2010-01-08           6.417542        17.885094         88.083275
# ...                       ...              ...               ...
# 2020-12-24         129.679749        48.779102        352.967987
# 2020-12-28         134.317810        49.436314        356.000275
# 2020-12-29         132.529388        49.408924        355.321106
# 2020-12-30         131.399399        49.691887        355.828125
# 2020-12-31         130.387207        50.057003        357.636017
#
#             (Close, AAPL)  (Close, KO)  (Close, SPY)  (High, AAPL)  \
# Date
# 2010-01-04       7.643214    28.520000    113.330002      7.660714
# 2010-01-05       7.656429    28.174999    113.629997      7.699643
# 2010-01-06       7.534643    28.165001    113.709999      7.686786
# 2010-01-07       7.520714    28.094999    114.190002      7.571429
# 2010-01-08       7.570714    27.575001    114.570000      7.571429
# ...                   ...          ...           ...           ...
# 2020-12-24     131.970001    53.439999    369.000000    133.460007
# 2020-12-28     136.690002    54.160000    372.170013    137.339996
# 2020-12-29     134.869995    54.130001    371.459991    138.789993
# 2020-12-30     133.720001    54.439999    371.989990    135.990005
# 2020-12-31     132.690002    54.840000    373.880005    134.740005
#
#             (High, KO)  (High, SPY)  (Low, AAPL)  (Low, KO)  (Low, SPY)  \
# Date
# 2010-01-04   28.610001   113.389999     7.585000  28.450001  111.510002
# 2010-01-05   28.495001   113.680000     7.616071  28.070000  112.849998
# 2010-01-06   28.219999   113.989998     7.526786  27.990000  113.430000
# 2010-01-07   28.184999   114.330002     7.466071  27.875000  113.180000
# 2010-01-08   27.820000   114.620003     7.466429  27.375000  113.660004
# ...                ...          ...          ...        ...         ...
# 2020-12-24   53.549999   369.029999   131.100006  53.020000  367.450012
# 2020-12-28   54.439999   372.589996   133.509995  53.730000  371.070007
# 2020-12-29   54.490002   374.000000   134.339996  54.020000  370.829987
# 2020-12-30   54.630001   373.100006   133.399994  54.029999  371.570007
# 2020-12-31   54.930000   374.660004   131.720001  54.270000  371.230011
#
#             (Open, AAPL)  (Open, KO)  (Open, SPY)  (Volume, AAPL)  \
# Date
# 2010-01-04      7.622500   28.580000   112.370003       493729600
# 2010-01-05      7.664286   28.424999   113.260002       601904800
# 2010-01-06      7.656429   28.174999   113.519997       552160000
# 2010-01-07      7.562500   28.165001   113.500000       477131200
# 2010-01-08      7.510714   27.730000   113.889999       447610800
# ...                  ...         ...          ...             ...
# 2020-12-24    131.320007   53.020000   368.079987        54930100
# 2020-12-28    133.990005   53.849998   371.739990       124486200
# 2020-12-29    138.050003   54.450001   373.809998       121047300
# 2020-12-30    135.580002   54.049999   372.339996        96452100
# 2020-12-31    134.080002   54.450001   371.779999        99116600
#
#             (Volume, KO)  (Volume, SPY)
# Date
# 2010-01-04      13870400      118944600
# 2010-01-05      23172400      111579900
# 2010-01-06      19264600      116074400
# 2010-01-07      13234600      131091100
# 2010-01-08      28712400      126402800
# ...                  ...            ...
# 2020-12-24       3265500       26457900
# 2020-12-28       9020500       39000400
# 2020-12-29       8320600       53680500
# 2020-12-30       8142700       49455300
# 2020-12-31       8495000       78520700
#
# [2769 rows x 18 columns]

# %%
stocks.columns=pd.MultiIndex.from_tuples(stocks.columns)
stocks
# Out:
#              Adj Close                              Close             \
#                   AAPL         KO         SPY        AAPL         KO
# Date
# 2010-01-04    6.478999  18.498022   87.129974    7.643214  28.520000
# 2010-01-05    6.490201  18.274248   87.360603    7.656429  28.174999
# 2010-01-06    6.386965  18.267769   87.422081    7.534643  28.165001
# 2010-01-07    6.375156  18.222361   87.791130    7.520714  28.094999
# 2010-01-08    6.417542  17.885094   88.083275    7.570714  27.575001
# ...                ...        ...         ...         ...        ...
# 2020-12-24  129.679749  48.779102  352.967987  131.970001  53.439999
# 2020-12-28  134.317810  49.436314  356.000275  136.690002  54.160000
# 2020-12-29  132.529388  49.408924  355.321106  134.869995  54.130001
# 2020-12-30  131.399399  49.691887  355.828125  133.720001  54.439999
# 2020-12-31  130.387207  50.057003  357.636017  132.690002  54.840000
#
#                               High                                Low  \
#                    SPY        AAPL         KO         SPY        AAPL
# Date
# 2010-01-04  113.330002    7.660714  28.610001  113.389999    7.585000
# 2010-01-05  113.629997    7.699643  28.495001  113.680000    7.616071
# 2010-01-06  113.709999    7.686786  28.219999  113.989998    7.526786
# 2010-01-07  114.190002    7.571429  28.184999  114.330002    7.466071
# 2010-01-08  114.570000    7.571429  27.820000  114.620003    7.466429
# ...                ...         ...        ...         ...         ...
# 2020-12-24  369.000000  133.460007  53.549999  369.029999  131.100006
# 2020-12-28  372.170013  137.339996  54.439999  372.589996  133.509995
# 2020-12-29  371.459991  138.789993  54.490002  374.000000  134.339996
# 2020-12-30  371.989990  135.990005  54.630001  373.100006  133.399994
# 2020-12-31  373.880005  134.740005  54.930000  374.660004  131.720001
#
#                                          Open                         \
#                    KO         SPY        AAPL         KO         SPY
# Date
# 2010-01-04  28.450001  111.510002    7.622500  28.580000  112.370003
# 2010-01-05  28.070000  112.849998    7.664286  28.424999  113.260002
# 2010-01-06  27.990000  113.430000    7.656429  28.174999  113.519997
# 2010-01-07  27.875000  113.180000    7.562500  28.165001  113.500000
# 2010-01-08  27.375000  113.660004    7.510714  27.730000  113.889999
# ...               ...         ...         ...        ...         ...
# 2020-12-24  53.020000  367.450012  131.320007  53.020000  368.079987
# 2020-12-28  53.730000  371.070007  133.990005  53.849998  371.739990
# 2020-12-29  54.020000  370.829987  138.050003  54.450001  373.809998
# 2020-12-30  54.029999  371.570007  135.580002  54.049999  372.339996
# 2020-12-31  54.270000  371.230011  134.080002  54.450001  371.779999
#
#                Volume
#                  AAPL        KO        SPY
# Date
# 2010-01-04  493729600  13870400  118944600
# 2010-01-05  601904800  23172400  111579900
# 2010-01-06  552160000  19264600  116074400
# 2010-01-07  477131200  13234600  131091100
# 2010-01-08  447610800  28712400  126402800
# ...               ...       ...        ...
# 2020-12-24   54930100   3265500   26457900
# 2020-12-28  124486200   9020500   39000400
# 2020-12-29  121047300   8320600   53680500
# 2020-12-30   96452100   8142700   49455300
# 2020-12-31   99116600   8495000   78520700
#
# [2769 rows x 18 columns]

# %%
stocks.columns
# Out:
# MultiIndex([('Adj Close', 'AAPL'),
#             ('Adj Close',   'KO'),
#             ('Adj Close',  'SPY'),
#             (    'Close', 'AAPL'),
#             (    'Close',   'KO'),
#             (    'Close',  'SPY'),
#             (     'High', 'AAPL'),
#             (     'High',   'KO'),
#             (     'High',  'SPY'),
#             (      'Low', 'AAPL'),
#             (      'Low',   'KO'),
#             (      'Low',  'SPY'),
#             (     'Open', 'AAPL'),
#             (     'Open',   'KO'),
#             (     'Open',  'SPY'),
#             (   'Volume', 'AAPL'),
#             (   'Volume',   'KO'),
#             (   'Volume',  'SPY')],
#            )

# %%
stocks.describe()
# Out:
#          Adj Close                                  Close               \
#               AAPL           KO          SPY         AAPL           KO
# count  2769.000000  2769.000000  2769.000000  2769.000000  2769.000000
# mean     31.562566    32.208758   182.052368    33.777537    41.320121
# std      24.614793     8.183724    69.703575    24.572747     6.808527
# min       5.814176    16.373825    79.271957     6.858929    25.014999
# 25%      15.201321    26.605547   114.881248    17.484285    37.660000
# 50%      24.549253    31.768911   175.981033    26.987499    41.759998
# 75%      40.931633    37.628510   241.932724    43.007500    45.549999
# max     134.317810    53.069546   357.636017   136.690002    60.130001
#
#                            High                                    Low  \
#                SPY         AAPL           KO          SPY         AAPL
# count  2769.000000  2769.000000  2769.000000  2769.000000  2769.000000
# mean    207.676797    34.114230    41.583236   208.716963    33.413543
# std      67.240791    24.895185     6.864731    67.589965    24.220789
# min     102.199997     7.000000    25.150000   103.419998     6.794643
# 25%     141.559998    17.695356    37.919998   142.100006    17.333929
# 50%     205.210007    27.225000    41.980000   206.190002    26.705000
# 75%     265.339996    43.367500    45.799999   267.320007    42.605000
# max     373.880005   138.789993    60.130001   378.459991   134.339996
#
#                                         Open                            \
#                 KO          SPY         AAPL           KO          SPY
# count  2769.000000  2769.000000  2769.000000  2769.000000  2769.000000
# mean     41.042551   206.475522    33.764375    41.314411   207.648136
# std       6.755616    66.883703    24.561595     6.807492    67.258092
# min      24.735001   101.129997     6.870357    25.110001   103.110001
# 25%      37.419998   140.929993    17.518213    37.700001   141.660004
# 50%      41.529999   204.110001    26.975000    41.750000   204.960007
# 75%      45.310001   263.390015    43.012501    45.549999   265.779999
# max      59.619999   371.570007   138.050003    59.810001   373.809998
#
#              Volume
#                AAPL            KO           SPY
# count  2.769000e+03  2.769000e+03  2.769000e+03
# mean   2.866162e+08  1.502133e+07  1.244573e+08
# std    2.289459e+08  6.716946e+06  7.477756e+07
# min    4.544800e+07  2.996300e+06  2.027000e+07
# 25%    1.211120e+08  1.071810e+07  7.292670e+07
# 50%    2.029972e+08  1.350830e+07  1.045961e+08
# 75%    3.890376e+08  1.751480e+07  1.539926e+08
# max    1.880998e+09  9.896750e+07  7.178287e+08

# %%
close=stocks.loc[:,"Close"].copy()

# %%
close
# Out:
#                   AAPL         KO         SPY
# Date
# 2010-01-04    7.643214  28.520000  113.330002
# 2010-01-05    7.656429  28.174999  113.629997
# 2010-01-06    7.534643  28.165001  113.709999
# 2010-01-07    7.520714  28.094999  114.190002
# 2010-01-08    7.570714  27.575001  114.570000
# ...                ...        ...         ...
# 2020-12-24  131.970001  53.439999  369.000000
# 2020-12-28  136.690002  54.160000  372.170013
# 2020-12-29  134.869995  54.130001  371.459991
# 2020-12-30  133.720001  54.439999  371.989990
# 2020-12-31  132.690002  54.840000  373.880005
#
# [2769 rows x 3 columns]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use("seaborn")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File c:\Python311\Lib\site-packages\matplotlib\style\core.py:137, in use(style)
#     136 try:
# --> 137     style = _rc_params_in_file(style)
#     138 except OSError as err:
#
# File c:\Python311\Lib\site-packages\matplotlib\__init__.py:879, in _rc_params_in_file(fname, transform, fail_on_error)
#     878 rc_temp = {}
# --> 879 with _open_file_or_url(fname) as fd:
#     880     try:
#
# File c:\Python311\Lib\contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#
# File c:\Python311\Lib\site-packages\matplotlib\__init__.py:856, in _open_file_or_url(fname)
#     855 fname = os.path.expanduser(fname)
# --> 856 with open(fname, encoding='utf-8') as f:
#     857     yield f
#
# FileNotFoundError: [Errno 2] No such file or directory: 'seaborn'
#
# The above exception was the direct cause of the following exception:
#
# OSError                                   Traceback (most recent call last)
# c:\Users\aidan_1k98io6\OneDrive - University of Suffolk\projects\Python, extra\algorithmic trading\main.ipynb Cell 25 line 3
#       <a href='vscode-notebook-cell:/c%3A/Users/aidan_1k98io6/OneDrive%20-%20University%20of%20Suffolk/projects/Python%2C%20extra/algorithmic%20trading/main.ipynb#X33sZmlsZQ%3D%3D?line=0'>1</a> get_ipython().run_line_magic('matplotlib', 'inline')
#       <a href='vscode-notebook-cell:/c%3A/Users/aidan_1k98io6/OneDrive%20-%20University%20of%20Suffolk/projects/Python%2C%20extra/algorithmic%20trading/main.ipynb#X33sZmlsZQ%3D%3D?line=1'>2</a> import matplotlib.pyplot as plt
# ----> <a href='vscode-notebook-cell:/c%3A/Users/aidan_1k98io6/OneDrive%20-%20University%20of%20Suffolk/projects/Python%2C%20extra/algorithmic%20trading/main.ipynb#X33sZmlsZQ%3D%3D?line=2'>3</a> plt.style.use("seaborn")
#
# File c:\Python311\Lib\site-packages\matplotlib\style\core.py:139, in use(style)
#     137         style = _rc_params_in_file(style)
#     138     except OSError as err:
# --> 139         raise OSError(
#     140             f"{style!r} is not a valid package style, path of style "
#     141             f"file, URL of style file, or library style name (library "
#     142             f"styles are listed in `style.available`)") from err
#     143 filtered = {}
#     144 for k in style:  # don't trigger RcParams.__getitem__('backend')
#
# OSError: 'seaborn' is not a valid package style, path of style file, URL of style file, or library style name (library styles are listed in `style.available`)

# %%
close.plot(figsize=(15,8),fontsize=12)
plt.legend(fontsize=12)
plt.show()

# %%
close.iloc[0,0]
# Out:
# 7.643214225769043

# %%
close.AAPL
# Out:
# Date
# 2010-01-04      7.643214
# 2010-01-05      7.656429
# 2010-01-06      7.534643
# 2010-01-07      7.520714
# 2010-01-08      7.570714
#                  ...
# 2020-12-24    131.970001
# 2020-12-28    136.690002
# 2020-12-29    134.869995
# 2020-12-30    133.720001
# 2020-12-31    132.690002
# Name: AAPL, Length: 2769, dtype: float64

# %%
close.AAPL.div(close.iloc[0,0])
# Out:
# Date
# 2010-01-04     1.000000
# 2010-01-05     1.001729
# 2010-01-06     0.985795
# 2010-01-07     0.983973
# 2010-01-08     0.990514
#                 ...
# 2020-12-24    17.266296
# 2020-12-28    17.883838
# 2020-12-29    17.645717
# 2020-12-30    17.495258
# 2020-12-31    17.360498
# Name: AAPL, Length: 2769, dtype: float64

# %%
close.AAPL.div(close.iloc[0,0]).mul(100)
# Out:
# Date
# 2010-01-04     100.000000
# 2010-01-05     100.172893
# 2010-01-06      98.579511
# 2010-01-07      98.397266
# 2010-01-08      99.051443
#                  ...
# 2020-12-24    1726.629626
# 2020-12-28    1788.383766
# 2020-12-29    1764.571699
# 2020-12-30    1749.525753
# 2020-12-31    1736.049763
# Name: AAPL, Length: 2769, dtype: float64

# %%
close.iloc[0]
# Out:
# AAPL      7.643214
# KO       28.520000
# SPY     113.330002
# Name: 2010-01-04 00:00:00, dtype: float64

# %%
close.div(close.iloc[0].mul(100))
# Out:
#                 AAPL        KO       SPY
# Date
# 2010-01-04  0.010000  0.010000  0.010000
# 2010-01-05  0.010017  0.009879  0.010026
# 2010-01-06  0.009858  0.009876  0.010034
# 2010-01-07  0.009840  0.009851  0.010076
# 2010-01-08  0.009905  0.009669  0.010109
# ...              ...       ...       ...
# 2020-12-24  0.172663  0.018738  0.032560
# 2020-12-28  0.178838  0.018990  0.032839
# 2020-12-29  0.176457  0.018980  0.032777
# 2020-12-30  0.174953  0.019088  0.032824
# 2020-12-31  0.173605  0.019229  0.032990
#
# [2769 rows x 3 columns]

# %%
normclose=close.div(close.iloc[0]).mul(100)

# %%
normclose.plot(figsize=(15,8),fontsize=12)
plt.legend(fontsize=12)
plt.show()

# %%
aapl= close.AAPL.copy().to_frame()

# %%
aapl
# Out:
#                   AAPL
# Date
# 2010-01-04    7.643214
# 2010-01-05    7.656429
# 2010-01-06    7.534643
# 2010-01-07    7.520714
# 2010-01-08    7.570714
# ...                ...
# 2020-12-24  131.970001
# 2020-12-28  136.690002
# 2020-12-29  134.869995
# 2020-12-30  133.720001
# 2020-12-31  132.690002
#
# [2769 rows x 1 columns]

# %%
aapl.shift(periods=1)
# Out:
#                   AAPL
# Date
# 2010-01-04         NaN
# 2010-01-05    7.643214
# 2010-01-06    7.656429
# 2010-01-07    7.534643
# 2010-01-08    7.520714
# ...                ...
# 2020-12-24  130.960007
# 2020-12-28  131.970001
# 2020-12-29  136.690002
# 2020-12-30  134.869995
# 2020-12-31  133.720001
#
# [2769 rows x 1 columns]

# %%
aapl["lag1"]=aapl.shift(periods=1)

# %%
aapl
# Out:
#                   AAPL        lag1
# Date
# 2010-01-04    7.643214         NaN
# 2010-01-05    7.656429    7.643214
# 2010-01-06    7.534643    7.656429
# 2010-01-07    7.520714    7.534643
# 2010-01-08    7.570714    7.520714
# ...                ...         ...
# 2020-12-24  131.970001  130.960007
# 2020-12-28  136.690002  131.970001
# 2020-12-29  134.869995  136.690002
# 2020-12-30  133.720001  134.869995
# 2020-12-31  132.690002  133.720001
#
# [2769 rows x 2 columns]

# %%
aapl.AAPL.sub(aapl.lag1)
# Out:
# Date
# 2010-01-04         NaN
# 2010-01-05    0.013215
# 2010-01-06   -0.121786
# 2010-01-07   -0.013929
# 2010-01-08    0.050000
#                 ...
# 2020-12-24    1.009995
# 2020-12-28    4.720001
# 2020-12-29   -1.820007
# 2020-12-30   -1.149994
# 2020-12-31   -1.029999
# Length: 2769, dtype: float64

# %%
aapl["Diff"]=aapl.AAPL.sub(aapl.lag1)

# %%
aapl
# Out:
#                   AAPL        lag1      Diff
# Date
# 2010-01-04    7.643214         NaN       NaN
# 2010-01-05    7.656429    7.643214  0.013215
# 2010-01-06    7.534643    7.656429 -0.121786
# 2010-01-07    7.520714    7.534643 -0.013929
# 2010-01-08    7.570714    7.520714  0.050000
# ...                ...         ...       ...
# 2020-12-24  131.970001  130.960007  1.009995
# 2020-12-28  136.690002  131.970001  4.720001
# 2020-12-29  134.869995  136.690002 -1.820007
# 2020-12-30  133.720001  134.869995 -1.149994
# 2020-12-31  132.690002  133.720001 -1.029999
#
# [2769 rows x 3 columns]

# %%
aapl["% Change"]=aapl.AAPL.div(aapl.lag1)

# %%
aapl
# Out:
#                   AAPL        lag1      Diff  % Change
# Date
# 2010-01-04    7.643214         NaN       NaN       NaN
# 2010-01-05    7.656429    7.643214  0.013215  1.001729
# 2010-01-06    7.534643    7.656429 -0.121786  0.984094
# 2010-01-07    7.520714    7.534643 -0.013929  0.998151
# 2010-01-08    7.570714    7.520714  0.050000  1.006648
# ...                ...         ...       ...       ...
# 2020-12-24  131.970001  130.960007  1.009995  1.007712
# 2020-12-28  136.690002  131.970001  4.720001  1.035766
# 2020-12-29  134.869995  136.690002 -1.820007  0.986685
# 2020-12-30  133.720001  134.869995 -1.149994  0.991473
# 2020-12-31  132.690002  133.720001 -1.029999  0.992297
#
# [2769 rows x 4 columns]

# %%
aapl["Diff2"]=aapl.AAPL.diff(periods=1)
aapl
# Out:
#                   AAPL        lag1      Diff  % Change     Diff2
# Date
# 2010-01-04    7.643214         NaN       NaN       NaN       NaN
# 2010-01-05    7.656429    7.643214  0.013215  1.001729  0.013215
# 2010-01-06    7.534643    7.656429 -0.121786  0.984094 -0.121786
# 2010-01-07    7.520714    7.534643 -0.013929  0.998151 -0.013929
# 2010-01-08    7.570714    7.520714  0.050000  1.006648  0.050000
# ...                ...         ...       ...       ...       ...
# 2020-12-24  131.970001  130.960007  1.009995  1.007712  1.009995
# 2020-12-28  136.690002  131.970001  4.720001  1.035766  4.720001
# 2020-12-29  134.869995  136.690002 -1.820007  0.986685 -1.820007
# 2020-12-30  133.720001  134.869995 -1.149994  0.991473 -1.149994
# 2020-12-31  132.690002  133.720001 -1.029999  0.992297 -1.029999
#
# [2769 rows x 5 columns]

# %%
aapl["% Change2"]=aapl.AAPL.pct_change(periods=1).mul(100)

# %%
aapl
# Out:
#                   AAPL        lag1      Diff  % Change     Diff2  % Change2
# Date
# 2010-01-04    7.643214         NaN       NaN       NaN       NaN        NaN
# 2010-01-05    7.656429    7.643214  0.013215  1.001729  0.013215   0.172893
# 2010-01-06    7.534643    7.656429 -0.121786  0.984094 -0.121786  -1.590632
# 2010-01-07    7.520714    7.534643 -0.013929  0.998151 -0.013929  -0.184871
# 2010-01-08    7.570714    7.520714  0.050000  1.006648  0.050000   0.664833
# ...                ...         ...       ...       ...       ...        ...
# 2020-12-24  131.970001  130.960007  1.009995  1.007712  1.009995   0.771224
# 2020-12-28  136.690002  131.970001  4.720001  1.035766  4.720001   3.576571
# 2020-12-29  134.869995  136.690002 -1.820007  0.986685 -1.820007  -1.331485
# 2020-12-30  133.720001  134.869995 -1.149994  0.991473 -1.149994  -0.852668
# 2020-12-31  132.690002  133.720001 -1.029999  0.992297 -1.029999  -0.770265
#
# [2769 rows x 6 columns]

# %%
del aapl["% Change"]

# %%
aapl
# Out:
#                   AAPL        lag1      Diff     Diff2  % Change2
# Date
# 2010-01-04    7.643214         NaN       NaN       NaN        NaN
# 2010-01-05    7.656429    7.643214  0.013215  0.013215   0.172893
# 2010-01-06    7.534643    7.656429 -0.121786 -0.121786  -1.590632
# 2010-01-07    7.520714    7.534643 -0.013929 -0.013929  -0.184871
# 2010-01-08    7.570714    7.520714  0.050000  0.050000   0.664833
# ...                ...         ...       ...       ...        ...
# 2020-12-24  131.970001  130.960007  1.009995  1.009995   0.771224
# 2020-12-28  136.690002  131.970001  4.720001  4.720001   3.576571
# 2020-12-29  134.869995  136.690002 -1.820007 -1.820007  -1.331485
# 2020-12-30  133.720001  134.869995 -1.149994 -1.149994  -0.852668
# 2020-12-31  132.690002  133.720001 -1.029999 -1.029999  -0.770265
#
# [2769 rows x 5 columns]

# %%
aapl.rename(columns={"% Change2":"% Change"},inplace=True)

# %%
aapl
# Out:
#                   AAPL        lag1      Diff     Diff2  % Change
# Date
# 2010-01-04    7.643214         NaN       NaN       NaN       NaN
# 2010-01-05    7.656429    7.643214  0.013215  0.013215  0.172893
# 2010-01-06    7.534643    7.656429 -0.121786 -0.121786 -1.590632
# 2010-01-07    7.520714    7.534643 -0.013929 -0.013929 -0.184871
# 2010-01-08    7.570714    7.520714  0.050000  0.050000  0.664833
# ...                ...         ...       ...       ...       ...
# 2020-12-24  131.970001  130.960007  1.009995  1.009995  0.771224
# 2020-12-28  136.690002  131.970001  4.720001  4.720001  3.576571
# 2020-12-29  134.869995  136.690002 -1.820007 -1.820007 -1.331485
# 2020-12-30  133.720001  134.869995 -1.149994 -1.149994 -0.852668
# 2020-12-31  132.690002  133.720001 -1.029999 -1.029999 -0.770265
#
# [2769 rows x 5 columns]

# %%
aapl.AAPL.resample("M").last()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\aidan_1k98io6\OneDrive - University of Suffolk\projects\Python, extra\algorithmic trading\main.ipynb Cell 52 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/aidan_1k98io6/OneDrive%20-%20University%20of%20Suffolk/projects/Python%2C%20extra/algorithmic%20trading/main.ipynb#Y102sZmlsZQ%3D%3D?line=0'>1</a> aapl.AAPL.resample("M").last()
#
# NameError: name 'aapl' is not defined

# %%
aapl.AAPL.resample("BM").last().pct_change(periods=1).mul(100)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\aidan_1k98io6\OneDrive - University of Suffolk\projects\Python, extra\algorithmic trading\main.ipynb Cell 53 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/aidan_1k98io6/OneDrive%20-%20University%20of%20Suffolk/projects/Python%2C%20extra/algorithmic%20trading/main.ipynb#Y103sZmlsZQ%3D%3D?line=0'>1</a> aapl.AAPL.resample("BM").last().pct_change(periods=1).mul(100)
#
# NameError: name 'aapl' is not defined

# %%
ret = aapl.pct_change().dropna()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\aidan_1k98io6\OneDrive - University of Suffolk\projects\Python, extra\algorithmic trading\main.ipynb Cell 54 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/aidan_1k98io6/OneDrive%20-%20University%20of%20Suffolk/projects/Python%2C%20extra/algorithmic%20trading/main.ipynb#Y104sZmlsZQ%3D%3D?line=0'>1</a> ret = aapl.pct_change().dropna()
#
# NameError: name 'aapl' is not defined

# %%
ret.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\aidan_1k98io6\OneDrive - University of Suffolk\projects\Python, extra\algorithmic trading\main.ipynb Cell 55 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/aidan_1k98io6/OneDrive%20-%20University%20of%20Suffolk/projects/Python%2C%20extra/algorithmic%20trading/main.ipynb#Y105sZmlsZQ%3D%3D?line=0'>1</a> ret.info()
#
# NameError: name 'ret' is not defined

# %%
ret.plot(kind="hist",figsize=(12,8),bins=100)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\aidan_1k98io6\OneDrive - University of Suffolk\projects\Python, extra\algorithmic trading\main.ipynb Cell 56 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/aidan_1k98io6/OneDrive%20-%20University%20of%20Suffolk/projects/Python%2C%20extra/algorithmic%20trading/main.ipynb#Y106sZmlsZQ%3D%3D?line=0'>1</a> ret.plot(kind="hist",figsize=(12,8),bins=100)
#       <a href='vscode-notebook-cell:/c%3A/Users/aidan_1k98io6/OneDrive%20-%20University%20of%20Suffolk/projects/Python%2C%20extra/algorithmic%20trading/main.ipynb#Y106sZmlsZQ%3D%3D?line=1'>2</a> plt.show()
#
# NameError: name 'ret' is not defined

# %%
daily_mean_ret=ret.mean()
daily_mean_ret
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\aidan_1k98io6\OneDrive - University of Suffolk\projects\Python, extra\algorithmic trading\main.ipynb Cell 57 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/aidan_1k98io6/OneDrive%20-%20University%20of%20Suffolk/projects/Python%2C%20extra/algorithmic%20trading/main.ipynb#Y110sZmlsZQ%3D%3D?line=0'>1</a> daily_mean_ret=ret.mean()
#       <a href='vscode-notebook-cell:/c%3A/Users/aidan_1k98io6/OneDrive%20-%20University%20of%20Suffolk/projects/Python%2C%20extra/algorithmic%20trading/main.ipynb#Y110sZmlsZQ%3D%3D?line=1'>2</a> daily_mean_ret
#
# NameError: name 'ret' is not defined

# %%
var_daily=ret.var()
var_daily
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\aidan_1k98io6\OneDrive - University of Suffolk\projects\Python, extra\algorithmic trading\main.ipynb Cell 58 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/aidan_1k98io6/OneDrive%20-%20University%20of%20Suffolk/projects/Python%2C%20extra/algorithmic%20trading/main.ipynb#Y111sZmlsZQ%3D%3D?line=0'>1</a> var_daily=ret.var()
#       <a href='vscode-notebook-cell:/c%3A/Users/aidan_1k98io6/OneDrive%20-%20University%20of%20Suffolk/projects/Python%2C%20extra/algorithmic%20trading/main.ipynb#Y111sZmlsZQ%3D%3D?line=1'>2</a> var_daily
#
# NameError: name 'ret' is not defined

# %%
std_daily=np.sqrt(var_daily)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\aidan_1k98io6\OneDrive - University of Suffolk\projects\Python, extra\algorithmic trading\main.ipynb Cell 59 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/aidan_1k98io6/OneDrive%20-%20University%20of%20Suffolk/projects/Python%2C%20extra/algorithmic%20trading/main.ipynb#Y112sZmlsZQ%3D%3D?line=0'>1</a> std_daily=np.sqrt(var_daily)
#
# NameError: name 'var_daily' is not defined

# %%
std_daily
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\aidan_1k98io6\OneDrive - University of Suffolk\projects\Python, extra\algorithmic trading\main.ipynb Cell 60 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/aidan_1k98io6/OneDrive%20-%20University%20of%20Suffolk/projects/Python%2C%20extra/algorithmic%20trading/main.ipynb#Y113sZmlsZQ%3D%3D?line=0'>1</a> std_daily
#
# NameError: name 'std_daily' is not defined

# %%
ret.std()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\aidan_1k98io6\OneDrive - University of Suffolk\projects\Python, extra\algorithmic trading\main.ipynb Cell 61 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/aidan_1k98io6/OneDrive%20-%20University%20of%20Suffolk/projects/Python%2C%20extra/algorithmic%20trading/main.ipynb#Y114sZmlsZQ%3D%3D?line=0'>1</a> ret.std()
#
# NameError: name 'ret' is not defined

# %%
annual_mean_ret=daily_mean_ret*252
annual_mean_ret
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\aidan_1k98io6\OneDrive - University of Suffolk\projects\Python, extra\algorithmic trading\main.ipynb Cell 62 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/aidan_1k98io6/OneDrive%20-%20University%20of%20Suffolk/projects/Python%2C%20extra/algorithmic%20trading/main.ipynb#Y115sZmlsZQ%3D%3D?line=0'>1</a> annual_mean_ret=daily_mean_ret*252
#       <a href='vscode-notebook-cell:/c%3A/Users/aidan_1k98io6/OneDrive%20-%20University%20of%20Suffolk/projects/Python%2C%20extra/algorithmic%20trading/main.ipynb#Y115sZmlsZQ%3D%3D?line=1'>2</a> annual_mean_ret
#
# NameError: name 'daily_mean_ret' is not defined

# %%
annual_var_return=var_daily*252#
annual_var_return
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\aidan_1k98io6\OneDrive - University of Suffolk\projects\Python, extra\algorithmic trading\main.ipynb Cell 63 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/aidan_1k98io6/OneDrive%20-%20University%20of%20Suffolk/projects/Python%2C%20extra/algorithmic%20trading/main.ipynb#Y116sZmlsZQ%3D%3D?line=0'>1</a> annual_var_return=var_daily*252#
#       <a href='vscode-notebook-cell:/c%3A/Users/aidan_1k98io6/OneDrive%20-%20University%20of%20Suffolk/projects/Python%2C%20extra/algorithmic%20trading/main.ipynb#Y116sZmlsZQ%3D%3D?line=1'>2</a> annual_var_return
#
# NameError: name 'var_daily' is not defined

# %%
annual_std_return=np.sqrt(annual_var_return)
annual_std_return
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\aidan_1k98io6\OneDrive - University of Suffolk\projects\Python, extra\algorithmic trading\main.ipynb Cell 64 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/aidan_1k98io6/OneDrive%20-%20University%20of%20Suffolk/projects/Python%2C%20extra/algorithmic%20trading/main.ipynb#Y120sZmlsZQ%3D%3D?line=0'>1</a> annual_std_return=np.sqrt(annual_var_return)
#       <a href='vscode-notebook-cell:/c%3A/Users/aidan_1k98io6/OneDrive%20-%20University%20of%20Suffolk/projects/Python%2C%20extra/algorithmic%20trading/main.ipynb#Y120sZmlsZQ%3D%3D?line=1'>2</a> annual_std_return
#
# NameError: name 'annual_var_return' is not defined

# %%
ret.std()*np.sqrt(252)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\aidan_1k98io6\OneDrive - University of Suffolk\projects\Python, extra\algorithmic trading\main.ipynb Cell 65 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/aidan_1k98io6/OneDrive%20-%20University%20of%20Suffolk/projects/Python%2C%20extra/algorithmic%20trading/main.ipynb#Y121sZmlsZQ%3D%3D?line=0'>1</a> ret.std()*np.sqrt(252)
#
# NameError: name 'ret' is not defined

# %%
ticker=["SPY","AAPL","KO","IBM","DIS","MSFT"]

# %%
stocks = yf.download(ticker, start='2010-01-01', end='2021-01-01')
# Out:
# [*********************100%%**********************]  6 of 6 completed

# %%
stocks
# Out:
#              Adj Close                                                 \
#                   AAPL         DIS         IBM         KO        MSFT
# Date
# 2010-01-04    6.478997   27.843174   77.467316  18.498013   23.474920
# 2010-01-05    6.490199   27.773722   76.531502  18.274254   23.482504
# 2010-01-06    6.386963   27.626123   76.034363  18.267765   23.338396
# 2010-01-07    6.375156   27.634811   75.771156  18.222363   23.095686
# 2010-01-08    6.417540   27.678215   76.531502  17.885086   23.254959
# ...                ...         ...         ...        ...         ...
# 2020-12-24  129.679733  173.165634  103.016937  48.779110  216.924286
# 2020-12-28  134.317825  178.278976  103.124352  49.436310  219.076477
# 2020-12-29  132.529404  176.724045  102.281647  49.408932  218.287674
# 2020-12-30  131.399368  180.581467  102.727776  49.691891  215.882263
# 2020-12-31  130.387207  180.591431  104.000107  50.057003  216.602905
#
#                              Close                                     ...  \
#                    SPY        AAPL         DIS         IBM         KO  ...
# Date                                                                   ...
# 2010-01-04   87.129967    7.643214   32.070000  126.625237  28.520000  ...
# 2010-01-05   87.360588    7.656429   31.990000  125.095604  28.174999  ...
# 2010-01-06   87.422081    7.534643   31.820000  124.282982  28.165001  ...
# 2010-01-07   87.791122    7.520714   31.830000  123.852776  28.094999  ...
# 2010-01-08   88.083275    7.570714   31.879999  125.095604  27.575001  ...
# ...                ...         ...         ...         ...        ...  ...
# 2020-12-24  352.967987  131.970001  173.729996  119.206497  53.439999  ...
# 2020-12-28  356.000336  136.690002  178.860001  119.330788  54.160000  ...
# 2020-12-29  355.321136  134.869995  177.300003  118.355644  54.130001  ...
# 2020-12-30  355.828064  133.720001  181.169998  118.871895  54.439999  ...
# 2020-12-31  357.636047  132.690002  181.179993  120.344170  54.840000  ...
#
#                   Open                                        Volume  \
#                    IBM         KO        MSFT         SPY       AAPL
# Date
# 2010-01-04  125.411087  28.580000   30.620001  112.370003  493729600
# 2010-01-05  125.889099  28.424999   30.850000  113.260002  601904800
# 2010-01-06  124.933075  28.174999   30.879999  113.519997  552160000
# 2010-01-07  124.158699  28.165001   30.629999  113.500000  477131200
# 2010-01-08  123.393883  27.730000   30.280001  113.889999  447610800
# ...                ...        ...         ...         ...        ...
# 2020-12-24  119.502869  53.020000  221.419998  368.079987   54930100
# 2020-12-28  119.598473  53.849998  224.449997  371.739990  124486200
# 2020-12-29  119.837479  54.450001  226.309998  373.809998  121047300
# 2020-12-30  118.355644  54.049999  225.229996  372.339996   96452100
# 2020-12-31  118.757172  54.450001  221.699997  371.779999   99116600
#
#
#                  DIS      IBM        KO      MSFT        SPY
# Date
# 2010-01-04  13700400  6438444  13870400  38409100  118944600
# 2010-01-05  10307700  7156104  23172400  49749600  111579900
# 2010-01-06  10709500  5863144  19264600  58182400  116074400
# 2010-01-07   8202100  6109268  13234600  50559700  131091100
# 2010-01-08   7657500  4390271  28712400  51197400  126402800
# ...              ...      ...       ...       ...        ...
# 2020-12-24   2721000  1842111   3265500  10550600   26457900
# 2020-12-28  13145400  3781499   9020500  17933500   39000400
# 2020-12-29   6875400  3647402   8320600  17403200   53680500
# 2020-12-30  11680400  3535794   8142700  20272300   49455300
# 2020-12-31   7073500  3738822   8495000  20942100   78520700
#
# [2769 rows x 36 columns]

# %%
close=stocks.loc[:,"Close"].copy()

# %%
normclose=close.div(close.iloc[0]).mul(100)

# %%
normclose.plot(figsize=(15,8),fontsize=12)
plt.legend(fontsize=12)
plt.show()

# %%
ret=close.pct_change().dropna()
ret.head()
# Out:
#                 AAPL       DIS       IBM        KO      MSFT       SPY
# Date
# 2010-01-05  0.001729 -0.002495 -0.012080 -0.012097  0.000323  0.002647
# 2010-01-06 -0.015906 -0.005314 -0.006496 -0.000355 -0.006137  0.000704
# 2010-01-07 -0.001849  0.000314 -0.003462 -0.002485 -0.010400  0.004221
# 2010-01-08  0.006648  0.001571  0.010035 -0.018509  0.006897  0.003328
# 2010-01-11 -0.008821 -0.016311 -0.010470  0.020308 -0.012720  0.001397

# %%
ret.describe().T
# Out:
#        count      mean       std       min       25%       50%       75%  \
# AAPL  2768.0  0.001191  0.017843 -0.128647 -0.007123  0.000903  0.010379
# DIS   2768.0  0.000749  0.015717 -0.129846 -0.006210  0.000629  0.007901
# IBM   2768.0  0.000082  0.014132 -0.128507 -0.006321  0.000287  0.006743
# KO    2768.0  0.000298  0.011088 -0.096725 -0.004698  0.000438  0.005706
# MSFT  2768.0  0.000841  0.016012 -0.147390 -0.006939  0.000654  0.008636
# SPY   2768.0  0.000491  0.010909 -0.109424 -0.003532  0.000637  0.005421
#
#            max
# AAPL  0.119808
# DIS   0.144123
# IBM   0.113010
# KO    0.064796
# MSFT  0.142169
# SPY   0.090603

# %%
summary=ret.describe().T.loc[:,["mean","std"]]
summary
# Out:
#           mean       std
# AAPL  0.001191  0.017843
# DIS   0.000749  0.015717
# IBM   0.000082  0.014132
# KO    0.000298  0.011088
# MSFT  0.000841  0.016012
# SPY   0.000491  0.010909

# %%
summary["mean"]=summary["mean"]*252
summary["std"]=summary["std"]*np.sqrt(252)
summary
# Out:
#           mean       std
# AAPL  0.300134  0.283242
# DIS   0.188696  0.249504
# IBM   0.020648  0.224345
# KO    0.075091  0.176009
# MSFT  0.211915  0.254185
# SPY   0.123754  0.173170

# %%
summary.plot.scatter(x="std",y="mean",figsize=(12,8),s=50,fontsize=15)
for i in summary.index:
    plt.annotate(i,xy=(summary.loc[i,"std"]+0.002,summary.loc[i,"mean"]+0.002),size=15)
plt.xlabel("Annual risk(std)",fontsize=15)
plt.ylabel("Annual return",fontsize=15)
plt.title("Risk/Return",fontsize=20)
# Out:
# Text(0.5, 1.0, 'Risk/Return')

# %%
fruits = ["apple","banana","mango"]
for i in fruits:
    print(i)
# Out:
# apple
# banana
# mango

# %%
fruits[1]
# Out:
# 'banana'

# %% [markdown]
# ## Correlation and Covariance

# %%
# comment

# %%
ret
# Out:
#                 AAPL       DIS       IBM        KO      MSFT       SPY
# Date
# 2010-01-05  0.001729 -0.002495 -0.012080 -0.012097  0.000323  0.002647
# 2010-01-06 -0.015906 -0.005314 -0.006496 -0.000355 -0.006137  0.000704
# 2010-01-07 -0.001849  0.000314 -0.003462 -0.002485 -0.010400  0.004221
# 2010-01-08  0.006648  0.001571  0.010035 -0.018509  0.006897  0.003328
# 2010-01-11 -0.008821 -0.016311 -0.010470  0.020308 -0.012720  0.001397
# ...              ...       ...       ...       ...       ...       ...
# 2020-12-24  0.007712  0.001037  0.006376  0.006782  0.007827  0.003890
# 2020-12-28  0.035766  0.029529  0.001043  0.013473  0.009921  0.008591
# 2020-12-29 -0.013315 -0.008722 -0.008172 -0.000554 -0.003601 -0.001908
# 2020-12-30 -0.008527  0.021827  0.004362  0.005727 -0.011019  0.001427
# 2020-12-31 -0.007703  0.000055  0.012385  0.007348  0.003338  0.005081
#
# [2768 rows x 6 columns]

# %%
ret.cov()
# Out:
#           AAPL       DIS       IBM        KO      MSFT       SPY
# AAPL  0.000318  0.000115  0.000110  0.000067  0.000158  0.000128
# DIS   0.000115  0.000247  0.000111  0.000085  0.000121  0.000121
# IBM   0.000110  0.000111  0.000200  0.000079  0.000121  0.000108
# KO    0.000067  0.000085  0.000079  0.000123  0.000076  0.000077
# MSFT  0.000158  0.000121  0.000121  0.000076  0.000256  0.000130
# SPY   0.000128  0.000121  0.000108  0.000077  0.000130  0.000119

# %%
ret.corr()
# Out:
#           AAPL       DIS       IBM        KO      MSFT       SPY
# AAPL  1.000000  0.408513  0.436100  0.339213  0.554051  0.659557
# DIS   0.408513  1.000000  0.497775  0.486514  0.480457  0.706726
# IBM   0.436100  0.497775  1.000000  0.502436  0.533130  0.703342
# KO    0.339213  0.486514  0.502436  1.000000  0.429749  0.639324
# MSFT  0.554051  0.480457  0.533130  0.429749  1.000000  0.744601
# SPY   0.659557  0.706726  0.703342  0.639324  0.744601  1.000000

# %%
import seaborn as sns

# %%
plt.figure(figsize=(12,8))
sns.set(font_scale=1.4)
sns.heatmap(ret.corr(),cmap="Reds",annot=True,annot_kws={"size":15},vmax=1)
plt.show()

# %% [markdown]
# # Simple returns and log returns

# %%
df = pd.DataFrame(index=[2016,2017,2018],data=[100,50,95],columns=["Price"])

# %%
df
# Out:
#       Price
# 2016    100
# 2017     50
# 2018     95

# %%
simplereturns=df.pct_change().dropna()
simplereturns
# Out:
#       Price
# 2017   -0.5
# 2018    0.9

# %%
simplereturns.mean()
# Out:
# Price    0.2
# dtype: float64

# %%
#Mean returns are misleading as crazy

# %%
logreturns=np.log(df/df.shift(1)).dropna()
logreturns
# Out:
#          Price
# 2017 -0.693147
# 2018  0.641854

# %%
logreturns.mean()
# Out:
# Price   -0.025647
# dtype: float64

# %%
100*np.exp(logreturns.mean()*2)
# Out:
# Price    95.0
# dtype: float64

# %%
SPY = yf.download("SPY")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
spy=SPY.Close.to_frame()

# %%
spy
# Out:
# Date
# 1993-01-29     43.937500
# 1993-02-01     44.250000
# 1993-02-02     44.343750
# 1993-02-03     44.812500
# 1993-02-04     45.000000
#                  ...
# 2023-12-13    470.500000
# 2023-12-14    472.010010
# 2023-12-15    469.329987
# 2023-12-18    471.970001
# 2023-12-19    474.839996
# Name: Close, Length: 7779, dtype: float64

# %%
spy.plot(figsize=(12,8),fontsize=15)
plt.legend(loc="upper left", fontsize=15)
plt.show()

# %%
spy_roll=spy.rolling(window=10)
spy_roll=spy_roll.mean()
spy_roll.head(15)
# Out:
#                 Close
# Date
# 1993-01-29        NaN
# 1993-02-01        NaN
# 1993-02-02        NaN
# 1993-02-03        NaN
# 1993-02-04        NaN
# 1993-02-05        NaN
# 1993-02-08        NaN
# 1993-02-09        NaN
# 1993-02-10        NaN
# 1993-02-11  44.659375
# 1993-02-12  44.725000
# 1993-02-16  44.646875
# 1993-02-17  44.556250
# 1993-02-18  44.415625
# 1993-02-19  44.271875

# %%
spy.rolling(window=10).median()
# Out:
#                  Close
# Date
# 1993-01-29         NaN
# 1993-02-01         NaN
# 1993-02-02         NaN
# 1993-02-03         NaN
# 1993-02-04         NaN
# ...                ...
# 2023-12-13  458.665009
# 2023-12-14  459.650009
# 2023-12-15  461.095001
# 2023-12-18  463.044998
# 2023-12-19  466.714996
#
# [7779 rows x 1 columns]

# %%
spy.rolling(window=10).max()
# Out:
#                  Close
# Date
# 1993-01-29         NaN
# 1993-02-01         NaN
# 1993-02-02         NaN
# 1993-02-03         NaN
# 1993-02-04         NaN
# ...                ...
# 2023-12-13  470.500000
# 2023-12-14  472.010010
# 2023-12-15  472.010010
# 2023-12-18  472.010010
# 2023-12-19  474.839996
#
# [7779 rows x 1 columns]

# %%
spy.rolling(window=10,min_periods=5).max().head(15)
# Out:
#                Close
# Date
# 1993-01-29       NaN
# 1993-02-01       NaN
# 1993-02-02       NaN
# 1993-02-03       NaN
# 1993-02-04  45.00000
# 1993-02-05  45.00000
# 1993-02-08  45.00000
# 1993-02-09  45.00000
# 1993-02-10  45.00000
# 1993-02-11  45.00000
# 1993-02-12  45.00000
# 1993-02-16  45.00000
# 1993-02-17  45.00000
# 1993-02-18  45.00000
# 1993-02-19  44.96875

# %%
spy
# Out:
#                  Close
# Date
# 1993-01-29   43.937500
# 1993-02-01   44.250000
# 1993-02-02   44.343750
# 1993-02-03   44.812500
# 1993-02-04   45.000000
# ...                ...
# 2023-12-13  470.500000
# 2023-12-14  472.010010
# 2023-12-15  469.329987
# 2023-12-18  471.970001
# 2023-12-19  474.839996
#
# [7779 rows x 1 columns]

# %%
spy["SMA50"]=spy.rolling(window=50,min_periods=50).mean()

# %%
spy.head(52)
# Out:
#                Close      SMA50
# Date
# 1993-01-29  43.93750        NaN
# 1993-02-01  44.25000        NaN
# 1993-02-02  44.34375        NaN
# 1993-02-03  44.81250        NaN
# 1993-02-04  45.00000  44.468750
# 1993-02-05  44.96875  44.552083
# 1993-02-08  44.96875  44.611607
# 1993-02-09  44.65625  44.617188
# 1993-02-10  44.71875  44.628472
# 1993-02-11  44.93750  44.659375
# 1993-02-12  44.59375  44.653409
# 1993-02-16  43.46875  44.554688
# 1993-02-17  43.43750  44.468750
# 1993-02-18  43.40625  44.392857
# 1993-02-19  43.56250  44.337500
# 1993-02-22  43.71875  44.298828
# 1993-02-23  43.68750  44.262868
# 1993-02-24  44.25000  44.262153
# 1993-02-25  44.34375  44.266447
# 1993-02-26  44.40625  44.273438
# 1993-03-01  44.28125  44.273810
# 1993-03-02  44.93750  44.303977
# 1993-03-03  45.12500  44.339674
# 1993-03-04  44.87500  44.361979
# 1993-03-05  44.75000  44.377500
# 1993-03-08  45.75000  44.430288
# 1993-03-09  45.59375  44.473380
# 1993-03-10  45.68750  44.516741
# 1993-03-11  45.56250  44.552802
# 1993-03-12  45.09375  44.570833
# 1993-03-15  45.31250  44.594758
# 1993-03-16  45.31250  44.617188
# 1993-03-17  45.03125  44.629735
# 1993-03-18  45.31250  44.649816
# 1993-03-19  45.03125  44.660714
# 1993-03-22  44.78125  44.664062
# 1993-03-23  44.87500  44.669764
# 1993-03-24  44.87500  44.675164
# 1993-03-25  45.15625  44.687500
# 1993-03-26  44.90625  44.692969
# 1993-03-29  45.09375  44.702744
# 1993-03-30  45.21875  44.715030
# 1993-03-31  45.18750  44.726017
# 1993-04-01  45.03125  44.732955
# 1993-04-02  44.09375  44.718750
# 1993-04-05  44.31250  44.709918
# 1993-04-06  44.18750  44.698803
# 1993-04-07  44.34375  44.691406
# 1993-04-08  44.28125  44.683036
# 1993-04-12  44.90625  44.687500
# 1993-04-13  45.00000  44.708750
# 1993-04-14  44.93750  44.722500

# %%
spy.plot(figsize=(12,8),fontsize=15)
plt.legend(loc="upper left", fontsize=15)
plt.show()

# %%
spy["SMA200"]=spy.Close.rolling(window=200,min_periods=200).mean()
spy
# Out:
#                  Close      SMA50      SMA200
# Date
# 1993-01-29   43.937500        NaN         NaN
# 1993-02-01   44.250000        NaN         NaN
# 1993-02-02   44.343750        NaN         NaN
# 1993-02-03   44.812500        NaN         NaN
# 1993-02-04   45.000000   44.46875         NaN
# ...                ...        ...         ...
# 2023-12-13  470.500000  440.16100  430.032901
# 2023-12-14  472.010010  441.10800  430.419251
# 2023-12-15  469.329987  442.00460  430.776851
# 2023-12-18  471.970001  442.85320  431.115751
# 2023-12-19  474.839996  443.70420  431.467601
#
# [7779 rows x 3 columns]

# %%
spy.plot(figsize=(12,8),fontsize=15)
plt.legend(loc="upper left", fontsize=15)
plt.show()

# %%
spy["EMA100"]=spy.Close.ewm(span=100,min_periods=100).mean()

# %%
spy
# Out:
#                  Close      SMA50      SMA200      EMA100
# Date
# 1993-01-29   43.937500        NaN         NaN         NaN
# 1993-02-01   44.250000        NaN         NaN         NaN
# 1993-02-02   44.343750        NaN         NaN         NaN
# 1993-02-03   44.812500        NaN         NaN         NaN
# 1993-02-04   45.000000   44.46875         NaN         NaN
# ...                ...        ...         ...         ...
# 2023-12-13  470.500000  440.16100  430.032901  440.604852
# 2023-12-14  472.010010  441.10800  430.419251  441.226736
# 2023-12-15  469.329987  442.00460  430.776851  441.783236
# 2023-12-18  471.970001  442.85320  431.115751  442.380994
# 2023-12-19  474.839996  443.70420  431.467601  443.023746
#
# [7779 rows x 4 columns]

# %%
spy.plot(figsize=(12,8),fontsize=15)
plt.legend(loc="upper left", fontsize=15)
plt.show()

# %%
spy["Day"]=spy.index.day_name()

# %%
spy["Quarter"]=spy.index.quarter

# %%
SPY = yf.download("SPY")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
spy
# Out:
#                  Close      SMA50      SMA200      EMA100        Day  Quarter
# Date
# 1993-01-29   43.937500        NaN         NaN         NaN     Friday        1
# 1993-02-01   44.250000        NaN         NaN         NaN     Monday        1
# 1993-02-02   44.343750        NaN         NaN         NaN    Tuesday        1
# 1993-02-03   44.812500        NaN         NaN         NaN  Wednesday        1
# 1993-02-04   45.000000   44.46875         NaN         NaN   Thursday        1
# ...                ...        ...         ...         ...        ...      ...
# 2023-12-13  470.500000  440.16100  430.032901  440.604852  Wednesday        4
# 2023-12-14  472.010010  441.10800  430.419251  441.226736   Thursday        4
# 2023-12-15  469.329987  442.00460  430.776851  441.783236     Friday        4
# 2023-12-18  471.970001  442.85320  431.115751  442.380994     Monday        4
# 2023-12-19  474.839996  443.70420  431.467601  443.023746    Tuesday        4
#
# [7779 rows x 6 columns]

# %%
all_days=pd.date_range(start="2010-01-01",end="2021-01-01",freq="D")
all_days
# Out:
# DatetimeIndex(['2010-01-01', '2010-01-02', '2010-01-03', '2010-01-04',
#                '2010-01-05', '2010-01-06', '2010-01-07', '2010-01-08',
#                '2010-01-09', '2010-01-10',
#                ...
#                '2020-12-23', '2020-12-24', '2020-12-25', '2020-12-26',
#                '2020-12-27', '2020-12-28', '2020-12-29', '2020-12-30',
#                '2020-12-31', '2021-01-01'],
#               dtype='datetime64[ns]', length=4019, freq='D')

# %%
spy
# Out:
#                  Close      SMA50      SMA200      EMA100        Day  Quarter
# Date
# 1993-01-29   43.937500        NaN         NaN         NaN     Friday        1
# 1993-02-01   44.250000        NaN         NaN         NaN     Monday        1
# 1993-02-02   44.343750        NaN         NaN         NaN    Tuesday        1
# 1993-02-03   44.812500        NaN         NaN         NaN  Wednesday        1
# 1993-02-04   45.000000   44.46875         NaN         NaN   Thursday        1
# ...                ...        ...         ...         ...        ...      ...
# 2023-12-13  470.500000  440.16100  430.032901  440.604852  Wednesday        4
# 2023-12-14  472.010010  441.10800  430.419251  441.226736   Thursday        4
# 2023-12-15  469.329987  442.00460  430.776851  441.783236     Friday        4
# 2023-12-18  471.970001  442.85320  431.115751  442.380994     Monday        4
# 2023-12-19  474.839996  443.70420  431.467601  443.023746    Tuesday        4
#
# [7779 rows x 6 columns]

# %%
spy=spy.reindex(all_days)

# %%
spy
# Out:
#                  Close       SMA50      SMA200      EMA100        Day  Quarter
# 2010-01-01         NaN         NaN         NaN         NaN        NaN      NaN
# 2010-01-02         NaN         NaN         NaN         NaN        NaN      NaN
# 2010-01-03         NaN         NaN         NaN         NaN        NaN      NaN
# 2010-01-04  113.330002  109.766200   98.780800  106.656766     Monday      1.0
# 2010-01-05  113.629997  109.852200   98.965400  106.794850    Tuesday      1.0
# ...                ...         ...         ...         ...        ...      ...
# 2020-12-28  372.170013  356.263202  320.936701  347.665329     Monday      4.0
# 2020-12-29  371.459991  356.746602  321.594751  348.136510    Tuesday      4.0
# 2020-12-30  371.989990  357.346201  322.190701  348.608856  Wednesday      4.0
# 2020-12-31  373.880005  357.956201  322.860101  349.109275   Thursday      4.0
# 2021-01-01         NaN         NaN         NaN         NaN        NaN      NaN
#
# [4019 rows x 6 columns]

# %%
spy.fillna(method="ffill")
# Out:
# C:\Users\aidan_1k98io6\AppData\Local\Temp\ipykernel_11072\3731869003.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   spy.fillna(method="ffill")
#                  Close       SMA50      SMA200      EMA100        Day  Quarter
# 2010-01-01         NaN         NaN         NaN         NaN        NaN      NaN
# 2010-01-02         NaN         NaN         NaN         NaN        NaN      NaN
# 2010-01-03         NaN         NaN         NaN         NaN        NaN      NaN
# 2010-01-04  113.330002  109.766200   98.780800  106.656766     Monday      1.0
# 2010-01-05  113.629997  109.852200   98.965400  106.794850    Tuesday      1.0
# ...                ...         ...         ...         ...        ...      ...
# 2020-12-28  372.170013  356.263202  320.936701  347.665329     Monday      4.0
# 2020-12-29  371.459991  356.746602  321.594751  348.136510    Tuesday      4.0
# 2020-12-30  371.989990  357.346201  322.190701  348.608856  Wednesday      4.0
# 2020-12-31  373.880005  357.956201  322.860101  349.109275   Thursday      4.0
# 2021-01-01  373.880005  357.956201  322.860101  349.109275   Thursday      4.0
#
# [4019 rows x 6 columns]

# %%
spy.fillna(method="bfill")
# Out:
# C:\Users\aidan_1k98io6\AppData\Local\Temp\ipykernel_11072\1752721331.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   spy.fillna(method="bfill")
#                  Close       SMA50      SMA200      EMA100        Day  Quarter
# 2010-01-01  113.330002  109.766200   98.780800  106.656766     Monday      1.0
# 2010-01-02  113.330002  109.766200   98.780800  106.656766     Monday      1.0
# 2010-01-03  113.330002  109.766200   98.780800  106.656766     Monday      1.0
# 2010-01-04  113.330002  109.766200   98.780800  106.656766     Monday      1.0
# 2010-01-05  113.629997  109.852200   98.965400  106.794850    Tuesday      1.0
# ...                ...         ...         ...         ...        ...      ...
# 2020-12-28  372.170013  356.263202  320.936701  347.665329     Monday      4.0
# 2020-12-29  371.459991  356.746602  321.594751  348.136510    Tuesday      4.0
# 2020-12-30  371.989990  357.346201  322.190701  348.608856  Wednesday      4.0
# 2020-12-31  373.880005  357.956201  322.860101  349.109275   Thursday      4.0
# 2021-01-01         NaN         NaN         NaN         NaN        NaN      NaN
#
# [4019 rows x 6 columns]

# %%
SPY = yf.download("SPY",interval="1wk")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
SPY
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1993-01-25   43.968750   43.968750   43.750000   43.937500   24.840675
# 1993-02-01   43.968750   45.093750   43.968750   44.968750   25.423702
# 1993-02-08   44.968750   45.125000   44.531250   44.593750   25.211691
# 1993-02-15   44.468750   44.468750   42.812500   43.562500   24.628672
# 1993-02-22   43.687500   44.437500   43.468750   44.406250   25.105682
# ...                ...         ...         ...         ...         ...
# 2023-11-20  450.529999  456.380005  450.519989  455.299988  453.461456
# 2023-11-27  454.649994  459.649994  453.339996  459.100006  457.246155
# 2023-12-04  455.600006  460.750000  454.309998  460.200012  458.341705
# 2023-12-11  459.690002  473.730011  459.470001  469.329987  467.434814
# 2023-12-18  470.980011  474.920013  469.890015  474.839996  474.839996
#
#                Volume
# Date
# 1993-01-25    1003200
# 1993-02-01    2234800
# 1993-02-08    1159800
# 1993-02-15     998700
# 1993-02-22    1024300
# ...               ...
# 2023-11-20  208313100
# 2023-11-27  344617600
# 2023-12-04  361425400
# 2023-12-11  486953100
# 2023-12-18  179259454
#
# [1613 rows x 6 columns]

# %% [markdown]
# Cumulative Returns, Drawdowns etc.

# %%
apple=yf.download("AAPL")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
apple=apple.Close.to_frame()

# %%
apple
# Out:
#                  Close
# Date
# 1980-12-12    0.128348
# 1980-12-15    0.121652
# 1980-12-16    0.112723
# 1980-12-17    0.115513
# 1980-12-18    0.118862
# ...                ...
# 2023-12-13  197.960007
# 2023-12-14  198.110001
# 2023-12-15  197.570007
# 2023-12-18  195.889999
# 2023-12-19  196.940002
#
# [10846 rows x 1 columns]

# %%
apple.Close
# Out:
# Date
# 1980-12-12      0.128348
# 1980-12-15      0.121652
# 1980-12-16      0.112723
# 1980-12-17      0.115513
# 1980-12-18      0.118862
#                  ...
# 2023-12-13    197.960007
# 2023-12-14    198.110001
# 2023-12-15    197.570007
# 2023-12-18    195.889999
# 2023-12-19    196.940002
# Name: Close, Length: 10846, dtype: float64

# %%
apple["d_returns"]=np.log(apple.div(apple.shift(1)))

# %%
apple
# Out:
#                  Close  d_returns
# Date
# 1980-12-12    0.128348        NaN
# 1980-12-15    0.121652  -0.053581
# 1980-12-16    0.112723  -0.076231
# 1980-12-17    0.115513   0.024450
# 1980-12-18    0.118862   0.028580
# ...                ...        ...
# 2023-12-13  197.960007   0.016554
# 2023-12-14  198.110001   0.000757
# 2023-12-15  197.570007  -0.002729
# 2023-12-18  195.889999  -0.008540
# 2023-12-19  196.940002   0.005346
#
# [10846 rows x 2 columns]

# %%
apple.dropna(inplace=True)

# %%
apple
# Out:
#                  Close  d_returns
# Date
# 1980-12-15    0.121652  -0.053581
# 1980-12-16    0.112723  -0.076231
# 1980-12-17    0.115513   0.024450
# 1980-12-18    0.118862   0.028580
# 1980-12-19    0.126116   0.059239
# ...                ...        ...
# 2023-12-13  197.960007   0.016554
# 2023-12-14  198.110001   0.000757
# 2023-12-15  197.570007  -0.002729
# 2023-12-18  195.889999  -0.008540
# 2023-12-19  196.940002   0.005346
#
# [10845 rows x 2 columns]

# %%
apple.d_returns.sum()
# Out:
# 7.33590913573612

# %%
np.exp(apple.d_returns.sum())
# Out:
# 1534.422144017485

# %%
apple["cummreturns"]=apple.d_returns.cumsum().apply(np.exp)

# %%
apple
# Out:
#                  Close  d_returns  cummreturns
# Date
# 1980-12-15    0.121652  -0.053581     0.947829
# 1980-12-16    0.112723  -0.076231     0.878261
# 1980-12-17    0.115513   0.024450     0.899998
# 1980-12-18    0.118862   0.028580     0.926092
# 1980-12-19    0.126116   0.059239     0.982610
# ...                ...        ...          ...
# 2023-12-13  197.960007   0.016554  1542.369321
# 2023-12-14  198.110001   0.000757  1543.537972
# 2023-12-15  197.570007  -0.002729  1539.330712
# 2023-12-18  195.889999  -0.008540  1526.241237
# 2023-12-19  196.940002   0.005346  1534.422144
#
# [10845 rows x 3 columns]

# %%
apple.cummreturns.plot(figsize=(12,8),title="Apple buy and hold",fontsize=15)
plt.show()

# %%
apple.d_returns.mean()*252
# Out:
# 0.17046095917063184

# %%
apple.d_returns.std()*np.sqrt(252)
# Out:
# 0.4517075921009182

# %%
# how to calculate drawdowns
apple["cummax"]=apple.cummreturns.cummax()

# %%
apple
# Out:
#                  Close  d_returns  cummreturns       cummax
# Date
# 1980-12-15    0.121652  -0.053581     0.947829     0.947829
# 1980-12-16    0.112723  -0.076231     0.878261     0.947829
# 1980-12-17    0.115513   0.024450     0.899998     0.947829
# 1980-12-18    0.118862   0.028580     0.926092     0.947829
# 1980-12-19    0.126116   0.059239     0.982610     0.982610
# ...                ...        ...          ...          ...
# 2023-12-13  197.960007   0.016554  1542.369321  1542.369321
# 2023-12-14  198.110001   0.000757  1543.537972  1543.537972
# 2023-12-15  197.570007  -0.002729  1539.330712  1543.537972
# 2023-12-18  195.889999  -0.008540  1526.241237  1543.537972
# 2023-12-19  196.940002   0.005346  1534.422144  1543.537972
#
# [10845 rows x 4 columns]

# %%
apple[["cummreturns","cummax"]].plot(figsize=(12,8),title="Apple buy and hold+cummax", fontsize=12)
plt.show()

# %%
apple["drawdown"]=apple["cummax"]-apple["cummreturns"]

# %%
apple
# Out:
#                  Close  d_returns  cummreturns       cummax   drawdown
# Date
# 1980-12-15    0.121652  -0.053581     0.947829     0.947829   0.000000
# 1980-12-16    0.112723  -0.076231     0.878261     0.947829   0.069569
# 1980-12-17    0.115513   0.024450     0.899998     0.947829   0.047831
# 1980-12-18    0.118862   0.028580     0.926092     0.947829   0.021738
# 1980-12-19    0.126116   0.059239     0.982610     0.982610   0.000000
# ...                ...        ...          ...          ...        ...
# 2023-12-13  197.960007   0.016554  1542.369321  1542.369321   0.000000
# 2023-12-14  198.110001   0.000757  1543.537972  1543.537972   0.000000
# 2023-12-15  197.570007  -0.002729  1539.330712  1543.537972   4.207259
# 2023-12-18  195.889999  -0.008540  1526.241237  1543.537972  17.296735
# 2023-12-19  196.940002   0.005346  1534.422144  1543.537972   9.115828
#
# [10845 rows x 5 columns]

# %%
apple.drawdown.max()
# Out:
# 444.02718404402026

# %%
apple.drawdown.idxmax()
# Out:
# Timestamp('2023-01-05 00:00:00')

# %%
apple.loc[(apple.index<='2020-09-18')]
# Out:
#                  Close  d_returns  cummreturns       cummax    drawdown
# Date
# 1980-12-15    0.121652  -0.053581     0.947829     0.947829    0.000000
# 1980-12-16    0.112723  -0.076231     0.878261     0.947829    0.069569
# 1980-12-17    0.115513   0.024450     0.899998     0.947829    0.047831
# 1980-12-18    0.118862   0.028580     0.926092     0.947829    0.021738
# 1980-12-19    0.126116   0.059239     0.982610     0.982610    0.000000
# ...                ...        ...          ...          ...         ...
# 2020-09-14  115.360001   0.029559   898.806425  1045.438964  146.632539
# 2020-09-15  115.540001   0.001559   900.208864  1045.438964  145.230099
# 2020-09-16  112.129997  -0.029958   873.640442  1045.438964  171.798522
# 2020-09-17  110.339996  -0.016092   859.693976  1045.438964  185.744988
# 2020-09-18  106.839996  -0.032234   832.424364  1045.438964  213.014600
#
# [10027 rows x 5 columns]

# %%
apple["drawdown%"]=(apple["cummax"]-apple["cummreturns"])/apple["cummax"]

# %%
apple
# Out:
#                  Close  d_returns  cummreturns       cummax   drawdown  \
# Date
# 1980-12-15    0.121652  -0.053581     0.947829     0.947829   0.000000
# 1980-12-16    0.112723  -0.076231     0.878261     0.947829   0.069569
# 1980-12-17    0.115513   0.024450     0.899998     0.947829   0.047831
# 1980-12-18    0.118862   0.028580     0.926092     0.947829   0.021738
# 1980-12-19    0.126116   0.059239     0.982610     0.982610   0.000000
# ...                ...        ...          ...          ...        ...
# 2023-12-13  197.960007   0.016554  1542.369321  1542.369321   0.000000
# 2023-12-14  198.110001   0.000757  1543.537972  1543.537972   0.000000
# 2023-12-15  197.570007  -0.002729  1539.330712  1543.537972   4.207259
# 2023-12-18  195.889999  -0.008540  1526.241237  1543.537972  17.296735
# 2023-12-19  196.940002   0.005346  1534.422144  1543.537972   9.115828
#
#             drawdown%
# Date
# 1980-12-15   0.000000
# 1980-12-16   0.073398
# 1980-12-17   0.050464
# 1980-12-18   0.022934
# 1980-12-19   0.000000
# ...               ...
# 2023-12-13   0.000000
# 2023-12-14   0.000000
# 2023-12-15   0.002726
# 2023-12-18   0.011206
# 2023-12-19   0.005906
#
# [10845 rows x 6 columns]

# %%
apple["drawdown%"].max()
# Out:
# 0.82216567924191

# %%
apple["drawdown%"].idxmax()
# Out:
# Timestamp('1997-12-23 00:00:00')

# %%
apple.loc[(apple.index<='1997-12-23')]
# Out:
#                Close  d_returns  cummreturns    cummax  drawdown  drawdown%
# Date
# 1980-12-15  0.121652  -0.053581     0.947829  0.947829  0.000000   0.000000
# 1980-12-16  0.112723  -0.076231     0.878261  0.947829  0.069569   0.073398
# 1980-12-17  0.115513   0.024450     0.899998  0.947829  0.047831   0.050464
# 1980-12-18  0.118862   0.028580     0.926092  0.947829  0.021738   0.022934
# 1980-12-19  0.126116   0.059239     0.982610  0.982610  0.000000   0.000000
# ...              ...        ...          ...       ...       ...        ...
# 1997-12-17  0.124442  -0.026549     0.969567  5.060882  4.091315   0.808419
# 1997-12-18  0.123326  -0.009008     0.960872  5.060882  4.100010   0.810137
# 1997-12-19  0.122210  -0.009090     0.952177  5.060882  4.108705   0.811856
# 1997-12-22  0.118862  -0.027778     0.926092  5.060882  4.134790   0.817010
# 1997-12-23  0.115513  -0.028580     0.899998  5.060882  4.160883   0.822166
#
# [4306 rows x 6 columns]

# %% [markdown]
# # SMA Strategy

# %%
data=apple.Close.loc[(apple.index>='1991-01-01')]

# %%
data=data.to_frame()

# %%
data
# Out:
#                  Close
# Date
# 1991-01-02    0.388393
# 1991-01-03    0.383929
# 1991-01-04    0.386161
# 1991-01-07    0.386161
# 1991-01-08    0.386161
# ...                ...
# 2023-12-13  197.960007
# 2023-12-14  198.110001
# 2023-12-15  197.570007
# 2023-12-18  195.889999
# 2023-12-19  196.940002
#
# [8305 rows x 1 columns]

# %%
sma_s=50
sma_l=100

# %%
data["sma_s"]=data.Close.rolling(sma_s).mean()
data["sma_l"]=data.Close.rolling(sma_l).mean()

# %%
data.plot(figsize=(12,8),title="AAPLE - SMA{} | SMA{}".format(sma_s,sma_l), fontsize=12)
# Out:
# <Axes: title={'center': 'AAPLE - SMA50 | SMA100'}, xlabel='Date'>

# %%
data.loc["2016"].plot(figsize=(12,8),title="AAPLE - SMA{} | SMA{}".format(sma_s,sma_l), fontsize=12)
# Out:
# <Axes: title={'center': 'AAPLE - SMA50 | SMA100'}, xlabel='Date'>

# %%
data.dropna(inplace=True)

# %%
data
# Out:
#                  Close       sma_s       sma_l
# Date
# 1991-05-23    0.402902    0.534420    0.513326
# 1991-05-24    0.409598    0.530960    0.513538
# 1991-05-28    0.410714    0.527344    0.513806
# 1991-05-29    0.419643    0.523638    0.514141
# 1991-05-30    0.425223    0.519732    0.514531
# ...                ...         ...         ...
# 2023-12-13  197.960007  182.845401  181.670201
# 2023-12-14  198.110001  183.334401  181.715101
# 2023-12-15  197.570007  183.787601  181.745801
# 2023-12-18  195.889999  184.155601  181.772501
# 2023-12-19  196.940002  184.514601  181.783601
#
# [8206 rows x 3 columns]

# %%
data["position"]=np.where(data["sma_s"]>data["sma_l"],1,-1)

# %%
data
# Out:
#                  Close       sma_s       sma_l  position
# Date
# 1991-05-23    0.402902    0.534420    0.513326         1
# 1991-05-24    0.409598    0.530960    0.513538         1
# 1991-05-28    0.410714    0.527344    0.513806         1
# 1991-05-29    0.419643    0.523638    0.514141         1
# 1991-05-30    0.425223    0.519732    0.514531         1
# ...                ...         ...         ...       ...
# 2023-12-13  197.960007  182.845401  181.670201         1
# 2023-12-14  198.110001  183.334401  181.715101         1
# 2023-12-15  197.570007  183.787601  181.745801         1
# 2023-12-18  195.889999  184.155601  181.772501         1
# 2023-12-19  196.940002  184.514601  181.783601         1
#
# [8206 rows x 4 columns]

# %%
data.loc["2016"].plot(figsize=(12,8),title="AAPLE - SMA{} | SMA{}".format(sma_s,sma_l), fontsize=12,secondary_y="position")
# Out:
# <Axes: title={'center': 'AAPLE - SMA50 | SMA100'}, xlabel='Date'>

# %%
data["returnsb&h"]=np.log(data.Close.div(data.Close.shift(1)))

# %%
data["strategy"]=data["returnsb&h"]*data.position.shift(1)

# %%
data
# Out:
#                  Close       sma_s       sma_l  position  returnsb&h  strategy
# Date
# 1991-05-23    0.402902    0.534420    0.513326         1         NaN       NaN
# 1991-05-24    0.409598    0.530960    0.513538         1    0.016483  0.016483
# 1991-05-28    0.410714    0.527344    0.513806         1    0.002721  0.002721
# 1991-05-29    0.419643    0.523638    0.514141         1    0.021507  0.021507
# 1991-05-30    0.425223    0.519732    0.514531         1    0.013209  0.013209
# ...                ...         ...         ...       ...         ...       ...
# 2023-12-13  197.960007  182.845401  181.670201         1    0.016554  0.016554
# 2023-12-14  198.110001  183.334401  181.715101         1    0.000757  0.000757
# 2023-12-15  197.570007  183.787601  181.745801         1   -0.002729 -0.002729
# 2023-12-18  195.889999  184.155601  181.772501         1   -0.008540 -0.008540
# 2023-12-19  196.940002  184.514601  181.783601         1    0.005346  0.005346
#
# [8206 rows x 6 columns]

# %%
data.dropna(inplace=True)

# %%
data[["returnsb&h", "strategy"]].sum()
# Out:
# returnsb&h    6.191961
# strategy      1.982655
# dtype: float64

# %%
data[['returnsb&h', 'strategy']].sum().apply(np.exp) # what 1$ would be worth
# Out:
# returnsb&h    488.803726
# strategy        7.261998
# dtype: float64

# %%
data[['returnsb&h', 'strategy']].std()*np.sqrt(252) #annual std
# Out:
# returnsb&h    0.435107
# strategy      0.435255
# dtype: float64

# %%
data.Close.plot(figsize=(12,8),fontsize=12)
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# Strategy adjusted with long bias

# %%
data["position2"]=np.where(data["sma_s"]>data["sma_l"],1,0)

# %%
data["strategy2"]=data["returnsb&h"]*data.position2.shift(1)

# %%
data.dropna(inplace=True)

# %%
data[["returnsb&h", "strategy2"]].sum()
# Out:
# returnsb&h    6.175478
# strategy2     4.070825
# dtype: float64

# %%
data[["returnsb&h","strategy2"]].sum().apply(np.exp)
# Out:
# returnsb&h    480.812909
# strategy2      58.605305
# dtype: float64

# %%
data[["returnsb&h","strategy2"]].std()*np.sqrt(252)
# Out:
# returnsb&h    0.435125
# strategy2     0.336346
# dtype: float64

# %%
## Strategy 2 is better than strategy 1
data[["strategy","strategy2"]].std()*np.sqrt(252)
# Out:
# strategy     0.435272
# strategy2    0.336346
# dtype: float64

# %% [markdown]
# # Creating our first function

# %%
def test_strategy(stock,start,end,SMA):
    df=yf.download(stock,start=start,end=end)
    data=df.Close.to_frame()
    data["returns"]=np.log(data.Close.div(data.Close.shift(1)))
    data["SMA_S"]=data.Close.rolling(SMA).mean()
    data["position"]=np.where(data["Close"]>data["SMA"],1,-1)
    data["strategy"]=data["returns"]*data["position"].shift(1)
    data.dropna(inplace=True)
    data["creturns"]=data["returns"].cumsum().apply(np.exp)
    data["cstrategy"]=data["strategy"].cumsum().apply(np.exp)
    perf=data[["creturns","cstrategy"]].iloc[-1]
    return perf

# %%
test_strategy("AAPL","2000-01-01","2020-01-01",(50,200))
# Out:
# [*********************100%%**********************]  1 of 1 completed
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\aidan_1k98io6\OneDrive - University of Suffolk\projects\Python, extra\algorithmic trading\main.ipynb Cell 184 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/aidan_1k98io6/OneDrive%20-%20University%20of%20Suffolk/projects/Python%2C%20extra/algorithmic%20trading/main.ipynb#Y360sZmlsZQ%3D%3D?line=0'>1</a> test_strategy("AAPL","2000-01-01","2020-01-01",(50,200))
#
# c:\Users\aidan_1k98io6\OneDrive - University of Suffolk\projects\Python, extra\algorithmic trading\main.ipynb Cell 184 line 5
#       <a href='vscode-notebook-cell:/c%3A/Users/aidan_1k98io6/OneDrive%20-%20University%20of%20Suffolk/projects/Python%2C%20extra/algorithmic%20trading/main.ipynb#Y360sZmlsZQ%3D%3D?line=2'>3</a> data=df.Close.to_frame()
#       <a href='vscode-notebook-cell:/c%3A/Users/aidan_1k98io6/OneDrive%20-%20University%20of%20Suffolk/projects/Python%2C%20extra/algorithmic%20trading/main.ipynb#Y360sZmlsZQ%3D%3D?line=3'>4</a> data["returns"]=np.log(data.Close.div(data.Close.shift(1)))
# ----> <a href='vscode-notebook-cell:/c%3A/Users/aidan_1k98io6/OneDrive%20-%20University%20of%20Suffolk/projects/Python%2C%20extra/algorithmic%20trading/main.ipynb#Y360sZmlsZQ%3D%3D?line=4'>5</a> data["SMA_S"]=data.Close.rolling(SMA).mean()
#       <a href='vscode-notebook-cell:/c%3A/Users/aidan_1k98io6/OneDrive%20-%20University%20of%20Suffolk/projects/Python%2C%20extra/algorithmic%20trading/main.ipynb#Y360sZmlsZQ%3D%3D?line=5'>6</a> data["position"]=np.where(data["Close"]>data["SMA"],1,-1)
#       <a href='vscode-notebook-cell:/c%3A/Users/aidan_1k98io6/OneDrive%20-%20University%20of%20Suffolk/projects/Python%2C%20extra/algorithmic%20trading/main.ipynb#Y360sZmlsZQ%3D%3D?line=6'>7</a> data["strategy"]=data["returns"]*data["position"].shift(1)
#
# File c:\Python311\Lib\site-packages\pandas\core\generic.py:12138, in NDFrame.rolling(self, window, min_periods, center, win_type, on, axis, closed, step, method)
#   12124 if win_type is not None:
#   12125     return Window(
#   12126         self,
#   12127         window=window,
#    (...)
#   12135         method=method,
#   12136     )
# > 12138 return Rolling(
#   12139     self,
#   12140     window=window,
#   12141     min_periods=min_periods,
#   12142     center=center,
#   12143     win_type=win_type,
#   12144     on=on,
#   12145     axis=axis,
#   12146     closed=closed,
#   12147     step=step,
#   12148     method=method,
#   12149 )
#
# File c:\Python311\Lib\site-packages\pandas\core\window\rolling.py:166, in BaseWindow.__init__(self, obj, window, min_periods, center, win_type, axis, on, closed, step, method, selection)
#     160     raise ValueError(
#     161         f"invalid on specified as {self.on}, "
#     162         "must be a column (of DataFrame), an Index or None"
#     163     )
#     165 self._selection = selection
# --> 166 self._validate()
#
# File c:\Python311\Lib\site-packages\pandas\core\window\rolling.py:1900, in Rolling._validate(self)
#    1898     pass
#    1899 elif not is_integer(self.window) or self.window < 0:
# -> 1900     raise ValueError("window must be an integer 0 or greater")
#
# ValueError: window must be an integer 0 or greater

# %% [markdown]
# # Creating our first class

# %%
class SMABacktester():
    def __init__(self,symbol,SMA_S, SMA_L,start,end):
        self.symbol=symbol
        self.SMA_S=SMA_S
        self.SMA_L=SMA_L
        self.start=start
        self.end=end
        self.results=None
        self.get_data()

    def get_data():
        df=yf.download(stock,start=self.start,end=self.end)
        data=df.Close.to_frame()
        data["returns"]=np.log(data.Close.div(data.Close.shift(1)))
        data["SMA_S"]=data.Close.rolling(self.SMA_S).mean()
        data["SMA_L"]=data.Close.rolling(self.SMA_L).mean()
        data.dropna(inplace=True)
        self.data2=data

        return data
    
    def test_results(self):
        data=self.data2.copy()
        data["position"]=np.where(data["SMA_S"]>data["SMA_L"],1,-1)
        data["strategy"]=data["returns"]*data["position"].shift(1)
        data.dropna(inplace=True)
        data["creturns"]=data["returns"].cumsum().apply(np.exp)
        data["cstrategy"]=data["strategy"].cumsum().apply(np.exp)
        perf=data[["creturns","cstrategy"]].iloc[-1]
        return perf
    
    def plot_results(self):
        if self.results is None:
            print("Run test_strategy() first")
        else:
            title="{} | SMA_S={} | SMA_L={}".format(self.symbol,self.SMA_S,self.SMA_L)
            self.results[["creturns","cstrategy"]].plot(figsize=(12,8),title=title,fontsize=12)
            plt.show()

# %%
tester = SMABacktester("AAPL",50,200,"2000-01-01","2020-01-01")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\aidan_1k98io6\OneDrive - University of Suffolk\projects\Python, extra\algorithmic trading\main.ipynb Cell 187 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/aidan_1k98io6/OneDrive%20-%20University%20of%20Suffolk/projects/Python%2C%20extra/algorithmic%20trading/main.ipynb#Y363sZmlsZQ%3D%3D?line=0'>1</a> tester = SMABacktester("AAPL",50,200,"2000-01-01","2020-01-01")
#
# c:\Users\aidan_1k98io6\OneDrive - University of Suffolk\projects\Python, extra\algorithmic trading\main.ipynb Cell 187 line 9
#       <a href='vscode-notebook-cell:/c%3A/Users/aidan_1k98io6/OneDrive%20-%20University%20of%20Suffolk/projects/Python%2C%20extra/algorithmic%20trading/main.ipynb#Y363sZmlsZQ%3D%3D?line=6'>7</a> self.end=end
#       <a href='vscode-notebook-cell:/c%3A/Users/aidan_1k98io6/OneDrive%20-%20University%20of%20Suffolk/projects/Python%2C%20extra/algorithmic%20trading/main.ipynb#Y363sZmlsZQ%3D%3D?line=7'>8</a> self.results=None
# ----> <a href='vscode-notebook-cell:/c%3A/Users/aidan_1k98io6/OneDrive%20-%20University%20of%20Suffolk/projects/Python%2C%20extra/algorithmic%20trading/main.ipynb#Y363sZmlsZQ%3D%3D?line=8'>9</a> self.get_data()
#
# TypeError: SMABacktester.get_data() takes 0 positional arguments but 1 was given

# %%
tester.plot_results()
